# %% [markdown]
# ## Библиотека pandas. Продолжение.

# %% [markdown]
# ### Группировка и агрегирование: методы `.groupby()` и `.agg()`

# %% [markdown]
# Часто случается, что данные необходимо сгруппировать по какому-то признаку ‒ по значениям определенной переменной. На входе имеется таблица (датафрейм), а на выходе хочется получить несколько таблиц: отдельная таблица для каждого значения. Давайте рассмотрим такой пример. У нас есть база данных с результатами выборов, и нам нужно сгруппировать данные по регионам.

# %% [markdown]
# Для начала импортируем библиотеку pandas и загрузим файл с данными.

# %%
import pandas as pd

# %% [markdown]
# Для разнообразия загрузим файл по ссылке с Github (база большая, загрузится не моментально):

# %%
df = pd.read_csv("https://raw.githubusercontent.com/allatambov/R-programming-3/master/lectures/lect7-12-01/47130-8314.csv")

# %% [markdown]
# В таблице сохранены результаты выборов президента России 2012 года.

# %%
df.head(2)
# Out:
#                                                 link  uik  \
# 0  http://www.adygei.vybory.izbirkom.ru/region/ad...    1
# 1  http://www.adygei.vybory.izbirkom.ru/region/ad...    2
#
#                          kom1        kom2    kom3  kom4  kom5       1       2  \
# 0  Республика Адыгея (Адыгея)  Адыгейская  УИК №1   NaN   NaN  2383.0  2147.0
# 1  Республика Адыгея (Адыгея)  Адыгейская  УИК №2   NaN   NaN  2865.0  2586.0
#
#      3  ...   18    19     20    21     22      23   а   б   в   г
# 0  0.0  ...  0.0  24.0  382.0  28.0   71.0  1066.0 NaN NaN NaN NaN
# 1  0.0  ...  0.0  51.0  453.0  49.0  104.0  1174.0 NaN NaN NaN NaN
#
# [2 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90003 entries, 0 to 90002
# Data columns (total 34 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   link    90003 non-null  object
#  1   uik     90003 non-null  int64
#  2   kom1    90003 non-null  object
#  3   kom2    90003 non-null  object
#  4   kom3    89618 non-null  object
#  5   kom4    0 non-null      float64
#  6   kom5    0 non-null      float64
#  7   1       89994 non-null  float64
#  8   2       89994 non-null  float64
#  9   3       89994 non-null  float64
#  10  4       89994 non-null  float64
#  11  5       89994 non-null  float64
#  12  6       89994 non-null  float64
#  13  7       89994 non-null  float64
#  14  8       89994 non-null  float64
#  15  9       89994 non-null  float64
#  16  10      89994 non-null  float64
#  17  11      89994 non-null  float64
#  18  12      89994 non-null  float64
#  19  13      89994 non-null  float64
#  20  14      89994 non-null  float64
#  21  15      89994 non-null  float64
#  22  16      89994 non-null  float64
#  23  17      89994 non-null  float64
#  24  18      89994 non-null  float64
#  25  19      89994 non-null  float64
#  26  20      89994 non-null  float64
#  27  21      89994 non-null  float64
#  28  22      89994 non-null  float64
#  29  23      89994 non-null  float64
#  30  а       0 non-null      float64
#  31  б       0 non-null      float64
#  32  в       0 non-null      float64
#  33  г       0 non-null      float64
# dtypes: float64(29), int64(1), object(4)
# memory usage: 23.3+ MB

# %% [markdown]
# Столбцы в этой базе имеют порядковый номер строки в таблице на сайте Центральной избирательной комиссии.
#
# Таблица достаточно большая, поэтому давайте выберем те столбцы, которые понадобятся нам для работы.
#
# Выберем столбцы, которые соответствуют уровням комиссий, а также следующим показателям: общее число зарегистрированных избирателей, число недействительных бюллетеней, число действительных бюллетеней, число голосов за Жириновского, Зюганова, Миронова, Прохорова и Путина.

# %%
d = df[["kom1", "kom2", "kom3", "1", "9", "10", "19", "20", "21", "22", "23"]]

# %%
d.head()
# Out:
#                          kom1        kom2    kom3       1     9      10    19  \
# 0  Республика Адыгея (Адыгея)  Адыгейская  УИК №1  2383.0  19.0  1571.0  24.0
# 1  Республика Адыгея (Адыгея)  Адыгейская  УИК №2  2865.0  29.0  1831.0  51.0
# 2  Республика Адыгея (Адыгея)  Адыгейская  УИК №3  2821.0  31.0  1673.0  36.0
# 3  Республика Адыгея (Адыгея)  Адыгейская  УИК №4  2069.0   0.0  1246.0   0.0
# 4  Республика Адыгея (Адыгея)  Адыгейская  УИК №5   777.0   8.0   454.0  19.0
#
#       20    21     22      23
# 0  382.0  28.0   71.0  1066.0
# 1  453.0  49.0  104.0  1174.0
# 2  481.0  24.0  107.0  1025.0
# 3  414.0   0.0   48.0   784.0
# 4  138.0   4.0    7.0   286.0

# %% [markdown]
# Теперь присвоим столбцам более информативные названия:

# %%
d.columns = ["region", "tik", "uik", "total", "invalid", "valid", "Zh", "Zu", "Mi", "Pr", "Pu"]

# %%
d.head() # опять посмотрим
# Out:
#                        region         tik     uik   total  invalid   valid  \
# 0  Республика Адыгея (Адыгея)  Адыгейская  УИК №1  2383.0     19.0  1571.0
# 1  Республика Адыгея (Адыгея)  Адыгейская  УИК №2  2865.0     29.0  1831.0
# 2  Республика Адыгея (Адыгея)  Адыгейская  УИК №3  2821.0     31.0  1673.0
# 3  Республика Адыгея (Адыгея)  Адыгейская  УИК №4  2069.0      0.0  1246.0
# 4  Республика Адыгея (Адыгея)  Адыгейская  УИК №5   777.0      8.0   454.0
#
#      Zh     Zu    Mi     Pr      Pu
# 0  24.0  382.0  28.0   71.0  1066.0
# 1  51.0  453.0  49.0  104.0  1174.0
# 2  36.0  481.0  24.0  107.0  1025.0
# 3   0.0  414.0   0.0   48.0   784.0
# 4  19.0  138.0   4.0    7.0   286.0

# %% [markdown]
# Посмотрим теперь, какие регионы есть в базе. Выбрать столбец *region* в таком случае будет не совсем удачно, поскольку в нем будет много повторяющихся значений. Посмотрим только на уникальные:

# %%
d.region.unique() # метод unique - уникальные значения
# Out:
# array(['Республика Адыгея (Адыгея)', 'Республика Алтай',
#        'Республика Башкортостан', 'Республика Бурятия',
#        'Республика Дагестан', 'Ðåñïóáëèêà Äàãåñòàí',
#        'Республика Ингушетия', 'Кабардино-Балкарская Республика',
#        'Республика Калмыкия', 'Карачаево-Черкесская Республика',
#        'Республика Карелия', 'Республика Коми', 'Республика Марий Эл',
#        'Республика Мордовия', 'Республика Саха (Якутия)',
#        'Республика Северная Осетия - Алания', 'Республика Тыва',
#        'Удмуртская Республика', 'Республика Хакасия',
#        'Чувашская Республика - Чувашия', 'Алтайский край',
#        'Забайкальский край', 'Камчатский край', 'Краснодарский край',
#        'Красноярский край', 'Пермский край', 'Приморский край',
#        'Ставропольский край', 'Хабаровский край', 'Õàáàðîâñêèé êðàé',
#        'Амурская область', 'Архангельская область',
#        'Астраханская область', 'Белгородская область', 'Брянская область',
#        'Владимирская область', 'Волгоградская область',
#        'Вологодская область', 'Воронежская область', 'Ивановская область',
#        'Иркутская область', 'Калужская область', 'Кемеровская область',
#        'Кировская область', 'Костромская область', 'Курганская область',
#        'Курская область', 'Ленинградская область', 'Липецкая область',
#        'Магаданская область', 'Московская область', 'Мурманская область',
#        'Ìóðìàíñêàÿ îáëàñòü', 'Нижегородская область',
#        'Новгородская область', 'Новосибирская область', 'Омская область',
#        'Оренбургская область', 'Орловская область', 'Пензенская область',
#        'Псковская область', 'Ростовская область', 'Рязанская область',
#        'Самарская область', 'Саратовская область', 'Сахалинская область',
#        'Свердловская область', 'Смоленская область', 'Тамбовская область',
#        'Тверская область', 'Томская область', 'Тульская область',
#        'Тюменская область', 'Ульяновская область', 'Челябинская область',
#        'Город Москва', 'Город Санкт-Петербург', 'Ãîðîä Ñàíêò-Ïåòåðáóðã',
#        'Еврейская автономная область', 'Ненецкий автономный округ',
#        'Чукотский автономный округ', 'Ямало-Ненецкий автономный округ',
#        'Город Байконур (Республика Казахстан)',
#        'Территория за пределами РФ'], dtype=object)

# %% [markdown]
# Видно, что в этом массиве встречаются какие-то названия со странной кодировкой. Уберем эти строки из базы.

# %%
# отфильтруем с помощью условий
d = d[(d.region != 'Ðåñïóáëèêà Äàãåñòàí') & 
  (d.region != 'Õàáàðîâñêèé êðàé') & 
  (d.region != 'Ìóðìàíñêàÿ îáëàñòü') & (d.region != 'Ãîðîä Ñàíêò-Ïåòåðáóðã')]

# %% [markdown]
# Сгруппируем данные по регионам и посчитаем для каждого региона явку в процентах и процент голосов за каждого кандидата. Группировка осуществляется с помощью метода `.groupby()`.

# %%
d.groupby('region') # пока ничего не увидели

# %% [markdown]
# Метод `.groupby()` создает список, состоящий из кортежей. Каждый кортеж ‒ это пара *название группы*-*соответствующий ей фрагмент датафрейма*.

# %%
# посмотрим на все сразу
for g in d.groupby('region'):
    print(g)
# Out:
# ('Алтайский край',                region                 tik       uik   total  invalid   valid  \
# 14416  Алтайский край            Алейская  УИК №517   577.0      2.0   368.0
# 14417  Алтайский край            Алейская  УИК №518   233.0      0.0   165.0
# 14418  Алтайский край            Алейская  УИК №519    46.0      0.0    36.0
# 14419  Алтайский край            Алейская  УИК №520   135.0      0.0   101.0
# 14420  Алтайский край            Алейская  УИК №521   185.0      0.0   146.0
# ...               ...                 ...       ...     ...      ...     ...
# 16273  Алтайский край  Яровская городская  УИК №512  2405.0     19.0  1553.0
# 16274  Алтайский край  Яровская городская  УИК №513  2338.0     22.0  1341.0
# 16275  Алтайский край  Яровская городская  УИК №514  2443.0     20.0  1529.0
# 16276  Алтайский край  Яровская городская  УИК №515  2387.0     17.0  1505.0
# 16277  Алтайский край  Яровская городская  УИК №516  2740.0     16.0  1711.0
#
#           Zh     Zu    Mi     Pr     Pu
# 14416   20.0   77.0   8.0   15.0  248.0
# 14417   22.0   60.0   2.0    8.0   73.0
# 14418    4.0    6.0   0.0    2.0   24.0
# 14419   14.0   12.0   2.0    5.0   68.0
# 14420   17.0   14.0   7.0    4.0  104.0
# ...      ...    ...   ...    ...    ...
# 16273  109.0  388.0  53.0  123.0  880.0
# 16274  124.0  288.0  38.0   90.0  801.0
# 16275  152.0  321.0  62.0  123.0  871.0
# 16276  101.0  348.0  42.0  114.0  900.0
# 16277  127.0  392.0  65.0  136.0  991.0
#
# [1862 rows x 11 columns])
# ('Амурская область',                  region             tik       uik   total  invalid   valid  \
# 28019  Амурская область     Архаринская    УИК №1  1522.0      7.0   704.0
# 28020  Амурская область     Архаринская    УИК №2  1461.0     10.0   866.0
# 28021  Амурская область     Архаринская    УИК №3  1487.0      9.0   781.0
# 28022  Амурская область     Архаринская    УИК №4  1593.0      6.0   878.0
# 28023  Амурская область     Архаринская    УИК №5  1481.0      8.0   737.0
# ...                 ...             ...       ...     ...      ...     ...
# 28797  Амурская область  (пгт) Прогресс  УИК №778  1837.0     10.0  1047.0
# 28798  Амурская область  (пгт) Прогресс  УИК №779   730.0      5.0   315.0
# 28799  Амурская область  (пгт) Прогресс  УИК №780   382.0      1.0   166.0
# 28800  Амурская область  (пгт) Прогресс  УИК №781   644.0      4.0   308.0
# 28801  Амурская область  (пгт) Прогресс  УИК №782   879.0      7.0   395.0
#
#           Zh     Zu    Mi    Pr     Pu
# 28019   69.0  121.0  20.0  27.0  467.0
# 28020   69.0  141.0  46.0  27.0  583.0
# 28021   58.0  141.0  28.0  34.0  520.0
# 28022  109.0  117.0  35.0  44.0  573.0
# 28023   74.0  150.0  22.0  40.0  451.0
# ...      ...    ...   ...   ...    ...
# 28797  106.0  278.0  38.0  67.0  558.0
# 28798   46.0   74.0   5.0   8.0  182.0
# 28799   17.0   43.0   2.0   5.0   99.0
# 28800   32.0   65.0  14.0   9.0  188.0
# 28801   40.0  105.0  10.0  19.0  221.0
#
# [783 rows x 11 columns])
# ('Архангельская область',                       region                         tik       uik   total  \
# 28802  Архангельская область  Архангельск, Исакогорская     УИК №1   752.0
# 28803  Архангельская область  Архангельск, Исакогорская     УИК №2   892.0
# 28804  Архангельская область  Архангельск, Исакогорская     УИК №3  1335.0
# 28805  Архангельская область  Архангельск, Исакогорская     УИК №4  2089.0
# 28806  Архангельская область  Архангельск, Исакогорская     УИК №5  1498.0
# ...                      ...                         ...       ...     ...
# 29781  Архангельская область                  Шенкурская  УИК №989   265.0
# 29782  Архангельская область                  Шенкурская  УИК №990   255.0
# 29783  Архангельская область                  Шенкурская  УИК №991  1343.0
# 29784  Архангельская область                  Шенкурская  УИК №992  1866.0
# 29785  Архангельская область                  Шенкурская  УИК №993  1475.0
#
#        invalid   valid    Zh     Zu    Mi     Pr     Pu
# 28802      3.0   321.0  23.0   30.0  20.0   29.0  219.0
# 28803      4.0   420.0  48.0   65.0  11.0   60.0  236.0
# 28804      4.0   633.0  65.0   79.0  46.0   55.0  388.0
# 28805     19.0  1134.0  94.0  164.0  61.0  125.0  690.0
# 28806      9.0   682.0  58.0   77.0  36.0  103.0  408.0
# ...        ...     ...   ...    ...   ...    ...    ...
# 29781      0.0   129.0  16.0   17.0   6.0    7.0   83.0
# 29782      0.0   174.0  27.0   24.0  12.0   22.0   89.0
# 29783      1.0   743.0  54.0   80.0  63.0   63.0  483.0
# 29784      7.0  1065.0  86.0  128.0  62.0  118.0  671.0
# 29785     11.0   845.0  66.0  102.0  68.0   82.0  527.0
#
# [984 rows x 11 columns])
# ('Астраханская область',                      region                   tik       uik   total  invalid  \
# 29786  Астраханская область  Астрахань, Кировская  УИК №382  1559.0     14.0
# 29787  Астраханская область  Астрахань, Кировская  УИК №383  2428.0      9.0
# 29788  Астраханская область  Астрахань, Кировская  УИК №384  1692.0      8.0
# 29789  Астраханская область  Астрахань, Кировская  УИК №385  2085.0     12.0
# 29790  Астраханская область  Астрахань, Кировская  УИК №386  1931.0      0.0
# ...                     ...                   ...       ...     ...      ...
# 30367  Астраханская область           Черноярская  УИК №377   323.0      2.0
# 30368  Астраханская область           Черноярская  УИК №378   767.0      6.0
# 30369  Астраханская область           Черноярская  УИК №379   740.0      4.0
# 30370  Астраханская область           Черноярская  УИК №380  1238.0      3.0
# 30371  Астраханская область           Черноярская  УИК №381  1183.0      5.0
#
#         valid    Zh     Zu     Mi     Pr      Pu
# 29786   828.0  38.0   80.0   31.0   32.0   647.0
# 29787  1486.0  79.0  265.0  108.0  234.0   800.0
# 29788   828.0  50.0  107.0   50.0   99.0   522.0
# 29789  1041.0  47.0  118.0   47.0   74.0   755.0
# 29790  1258.0  40.0   69.0   21.0    9.0  1119.0
# ...       ...   ...    ...    ...    ...     ...
# 30367   221.0  15.0   36.0    5.0    9.0   156.0
# 30368   472.0  21.0   96.0    9.0   20.0   326.0
# 30369   441.0  25.0  143.0    9.0   21.0   243.0
# 30370   744.0  37.0  152.0   22.0   27.0   506.0
# 30371   711.0  57.0  155.0   12.0   18.0   469.0
#
# [586 rows x 11 columns])
# ('Белгородская область',                      region           tik        uik   total  invalid   valid  \
# 30372  Белгородская область  Алексеевская     УИК №1  2303.0     19.0  1403.0
# 30373  Белгородская область  Алексеевская     УИК №2  2453.0     26.0  1494.0
# 30374  Белгородская область  Алексеевская     УИК №3  1629.0     14.0  1021.0
# 30375  Белгородская область  Алексеевская     УИК №4  2780.0     17.0  1693.0
# 30376  Белгородская область  Алексеевская     УИК №5  2495.0     16.0  1373.0
# ...                     ...           ...        ...     ...      ...     ...
# 31617  Белгородская область   Яковлевская  УИК №1249   241.0      1.0   213.0
# 31618  Белгородская область   Яковлевская  УИК №1250   588.0      8.0   530.0
# 31619  Белгородская область   Яковлевская  УИК №1251   221.0      2.0   197.0
# 31620  Белгородская область   Яковлевская  УИК №1252  1115.0      9.0   990.0
# 31621  Белгородская область   Яковлевская  УИК №1253   550.0      6.0   485.0
#
#           Zh     Zu    Mi     Pr      Pu
# 30372  103.0  316.0  78.0   72.0   834.0
# 30373  118.0  312.0  73.0  105.0   886.0
# 30374   84.0  246.0  46.0   52.0   593.0
# 30375  114.0  373.0  96.0   95.0  1015.0
# 30376  118.0  336.0  74.0   75.0   770.0
# ...      ...    ...   ...    ...     ...
# 31617   13.0   37.0   8.0   14.0   141.0
# 31618   38.0   73.0  12.0   17.0   390.0
# 31619    9.0   49.0   7.0   11.0   121.0
# 31620   53.0  150.0  27.0   42.0   718.0
# 31621   30.0  111.0  14.0   24.0   306.0
#
# [1250 rows x 11 columns])
# ('Брянская область',                  region         tik        uik   total  invalid  valid    Zh  \
# 31622  Брянская область  Брасовская   УИК №171  1188.0      5.0  704.0  47.0
# 31623  Брянская область  Брасовская   УИК №172   231.0      0.0  190.0  10.0
# 31624  Брянская область  Брасовская   УИК №173   318.0      4.0  255.0  10.0
# 31625  Брянская область  Брасовская   УИК №174   349.0      3.0  246.0  20.0
# 31626  Брянская область  Брасовская   УИК №175   530.0      3.0  417.0  34.0
# ...                 ...         ...        ...     ...      ...    ...   ...
# 32741  Брянская область    Унечская  УИК №1070   342.0      0.0  211.0  25.0
# 32742  Брянская область    Унечская  УИК №1071   487.0      3.0  294.0  30.0
# 32743  Брянская область    Унечская  УИК №1072   767.0      3.0  457.0  48.0
# 32744  Брянская область    Унечская  УИК №1073   235.0      2.0  157.0  14.0
# 32745  Брянская область    Унечская  УИК №1074   112.0      4.0   80.0   8.0
#
#           Zu    Mi    Pr     Pu
# 31622  165.0  16.0  24.0  452.0
# 31623   56.0   2.0   8.0  114.0
# 31624   44.0  10.0   7.0  184.0
# 31625   39.0   4.0   5.0  178.0
# 31626  104.0  10.0  18.0  251.0
# ...      ...   ...   ...    ...
# 32741   42.0   3.0   3.0  138.0
# 32742   72.0   7.0   6.0  179.0
# 32743   95.0  13.0  11.0  290.0
# 32744   35.0  13.0   2.0   93.0
# 32745   11.0   4.0   0.0   57.0
#
# [1124 rows x 11 columns])
# ('Владимирская область',                      region                  tik       uik   total  invalid  \
# 32746  Владимирская область  Владимир, Ленинская  УИК №347  2401.0     21.0
# 32747  Владимирская область  Владимир, Ленинская  УИК №348  2981.0     18.0
# 32748  Владимирская область  Владимир, Ленинская  УИК №349  2842.0     15.0
# 32749  Владимирская область  Владимир, Ленинская  УИК №350  2272.0     22.0
# 32750  Владимирская область  Владимир, Ленинская  УИК №351  1736.0     15.0
# ...                     ...                  ...       ...     ...      ...
# 33681  Владимирская область       Юрьев-Польская  УИК №288  1568.0     11.0
# 33682  Владимирская область       Юрьев-Польская  УИК №289   579.0      2.0
# 33683  Владимирская область       Юрьев-Польская  УИК №290   676.0      5.0
# 33684  Владимирская область       Юрьев-Польская  УИК №291   156.0      0.0
# 33685  Владимирская область       Юрьев-Польская  УИК №292   303.0      1.0
#
#         valid     Zh     Zu     Mi     Pr     Pu
# 32746  1582.0  111.0  342.0  124.0  255.0  750.0
# 32747  1789.0  150.0  400.0  109.0  252.0  878.0
# 32748  1523.0  106.0  350.0   99.0  201.0  767.0
# 32749  1192.0   74.0  291.0   85.0  163.0  579.0
# 32750   809.0   76.0  167.0   45.0  127.0  394.0
# ...       ...    ...    ...    ...    ...    ...
# 33681   726.0   60.0  129.0   36.0   56.0  445.0
# 33682   301.0   28.0   80.0   20.0   17.0  156.0
# 33683   377.0   35.0   70.0   27.0   20.0  225.0
# 33684   106.0    5.0   19.0    1.0    8.0   73.0
# 33685   201.0   22.0   41.0    5.0    1.0  132.0
#
# [940 rows x 11 columns])
# ('Волгоградская область',                       region            tik        uik   total  invalid  \
# 33686  Волгоградская область   Алексеевская   УИК №101  1475.0     11.0
# 33687  Волгоградская область   Алексеевская   УИК №102  1777.0      2.0
# 33688  Волгоградская область   Алексеевская   УИК №103  1147.0      0.0
# 33689  Волгоградская область   Алексеевская   УИК №104   463.0      3.0
# 33690  Волгоградская область   Алексеевская   УИК №105   133.0      1.0
# ...                      ...            ...        ...     ...      ...
# 35334  Волгоградская область  Чернышковская  УИК №4221   277.0      3.0
# 35335  Волгоградская область  Чернышковская  УИК №4222   426.0      5.0
# 35336  Волгоградская область  Чернышковская  УИК №4223   241.0      0.0
# 35337  Волгоградская область  Чернышковская  УИК №4224   277.0      2.0
# 35338  Волгоградская область  Чернышковская  УИК №4225   111.0      0.0
#
#         valid    Zh    Zu    Mi    Pr      Pu
# 33686   977.0  28.0  51.0  45.0  24.0   829.0
# 33687  1362.0  24.0  69.0  12.0  19.0  1238.0
# 33688   990.0  20.0  49.0  22.0  32.0   867.0
# 33689   392.0  17.0  22.0  11.0   5.0   337.0
# 33690   113.0   3.0   5.0   4.0   5.0    96.0
# ...       ...   ...   ...   ...   ...     ...
# 35334   219.0  30.0  12.0  12.0   3.0   162.0
# 35335   303.0  22.0  83.0  13.0   7.0   178.0
# 35336   182.0  15.0  31.0   8.0   3.0   125.0
# 35337   216.0  13.0  37.0   1.0   7.0   158.0
# 35338    88.0   7.0  18.0   7.0   6.0    50.0
#
# [1653 rows x 11 columns])
# ('Вологодская область',                     region          tik        uik   total  invalid   valid  \
# 35339  Вологодская область   Бабаевская     УИК №1  1194.0     10.0   696.0
# 35340  Вологодская область   Бабаевская     УИК №2  1202.0      5.0   745.0
# 35341  Вологодская область   Бабаевская     УИК №3  1106.0      5.0   622.0
# 35342  Вологодская область   Бабаевская     УИК №4  1062.0      9.0   704.0
# 35343  Вологодская область   Бабаевская     УИК №5  1055.0     12.0   688.0
# ...                    ...          ...        ...     ...      ...     ...
# 36374  Вологодская область  Шекснинская  УИК №1062    88.0      0.0    67.0
# 36375  Вологодская область  Шекснинская  УИК №1063   190.0      0.0   142.0
# 36376  Вологодская область  Шекснинская  УИК №1064   333.0      0.0   218.0
# 36377  Вологодская область  Шекснинская  УИК №1065   278.0      2.0   209.0
# 36378  Вологодская область  Шекснинская  УИК №1069  1854.0      8.0  1704.0
#
#          Zh     Zu    Mi    Pr      Pu
# 35339  48.0  109.0  64.0  51.0   424.0
# 35340  69.0  119.0  57.0  63.0   437.0
# 35341  45.0   82.0  55.0  59.0   381.0
# 35342  58.0  105.0  63.0  42.0   436.0
# 35343  58.0   93.0  69.0  59.0   409.0
# ...     ...    ...   ...   ...     ...
# 36374   8.0    6.0   2.0   1.0    50.0
# 36375  10.0   24.0   3.0   6.0    99.0
# 36376  33.0   26.0   6.0   5.0   148.0
# 36377  20.0   29.0  20.0   4.0   136.0
# 36378  88.0  139.0  69.0  75.0  1333.0
#
# [1040 rows x 11 columns])
# ('Воронежская область',                     region         tik        uik   total  invalid   valid  \
# 36379  Воронежская область   Аннинская   УИК №101  1164.0      0.0   965.0
# 36380  Воронежская область   Аннинская   УИК №102  1068.0      3.0   862.0
# 36381  Воронежская область   Аннинская   УИК №103  1551.0      2.0  1223.0
# 36382  Воронежская область   Аннинская   УИК №104  2186.0      9.0  1828.0
# 36383  Воронежская область   Аннинская   УИК №105  1480.0      5.0  1091.0
# ...                    ...         ...        ...     ...      ...     ...
# 38054  Воронежская область  Эртильская  УИК №3939   410.0      0.0   292.0
# 38055  Воронежская область  Эртильская  УИК №3940   835.0      5.0   522.0
# 38056  Воронежская область  Эртильская  УИК №3941   797.0      6.0   538.0
# 38057  Воронежская область  Эртильская  УИК №3942   473.0      3.0   262.0
# 38058  Воронежская область  Эртильская  УИК №3943   516.0      2.0   314.0
#
#          Zh     Zu    Mi    Pr      Pu
# 36379  16.0  144.0   7.0  25.0   773.0
# 36380  21.0  121.0   9.0  10.0   701.0
# 36381  61.0  184.0  17.0  19.0   942.0
# 36382  35.0  273.0  26.0  62.0  1432.0
# 36383  41.0  157.0  38.0  36.0   819.0
# ...     ...    ...   ...   ...     ...
# 38054  27.0   59.0   5.0  10.0   191.0
# 38055  49.0  120.0  21.0  15.0   317.0
# 38056  52.0  108.0  28.0  20.0   330.0
# 38057  28.0   56.0  13.0  14.0   151.0
# 38058  24.0   87.0  14.0  10.0   179.0
#
# [1680 rows x 11 columns])
# ('Город Байконур (Республика Казахстан)',                                       region        tik  uik   total  invalid  \
# 89618  Город Байконур (Республика Казахстан)  УИК №5348  NaN  2145.0     16.0
# 89619  Город Байконур (Республика Казахстан)  УИК №5349  NaN  2284.0     48.0
# 89620  Город Байконур (Республика Казахстан)  УИК №5350  NaN  2360.0     29.0
# 89621  Город Байконур (Республика Казахстан)  УИК №5351  NaN  1893.0     23.0
# 89622  Город Байконур (Республика Казахстан)  УИК №5352  NaN  1996.0     14.0
# 89623  Город Байконур (Республика Казахстан)  УИК №5353  NaN  2174.0     18.0
# 89624  Город Байконур (Республика Казахстан)  УИК №5354  NaN  2264.0     37.0
#
#         valid    Zh     Zu    Mi     Pr      Pu
# 89618  1605.0  72.0  197.0  52.0   99.0  1185.0
# 89619  1600.0  85.0  181.0  46.0  101.0  1187.0
# 89620  1635.0  84.0  170.0  45.0  112.0  1224.0
# 89621  1276.0  89.0  148.0  32.0   60.0   947.0
# 89622  1321.0  70.0  161.0  33.0  111.0   946.0
# 89623  1426.0  97.0  202.0  48.0  103.0   976.0
# 89624  1559.0  89.0  229.0  61.0  136.0  1044.0  )
# ('Город Москва',              region                    tik        uik   total  invalid  \
# 83827  Город Москва      район Богородское   УИК №843  1887.0     18.0
# 83828  Город Москва      район Богородское   УИК №844  2113.0     20.0
# 83829  Город Москва      район Богородское   УИК №845   311.0      0.0
# 83830  Город Москва      район Богородское   УИК №846  1823.0     20.0
# 83831  Город Москва      район Богородское   УИК №847  2875.0     38.0
# ...             ...                    ...        ...     ...      ...
# 87208  Город Москва  район Чертаново Южное  УИК №2046  2457.0     25.0
# 87209  Город Москва  район Чертаново Южное  УИК №2047  2522.0     26.0
# 87210  Город Москва  район Чертаново Южное  УИК №2048  2658.0     31.0
# 87211  Город Москва  район Чертаново Южное  УИК №2049  2634.0     19.0
# 87212  Город Москва  район Чертаново Южное  УИК №3344   764.0     38.0
#
#         valid     Zh     Zu    Mi     Pr     Pu
# 83827   998.0   61.0  211.0  50.0  195.0  481.0
# 83828  1134.0   99.0  198.0  70.0  205.0  562.0
# 83829   184.0   13.0   32.0   8.0   29.0  102.0
# 83830   996.0   94.0  178.0  49.0  185.0  490.0
# 83831  1593.0  121.0  316.0  88.0  319.0  749.0
# ...       ...    ...    ...   ...    ...    ...
# 87208  1506.0   91.0  360.0  67.0  280.0  708.0
# 87209  1279.0   92.0  256.0  69.0  222.0  640.0
# 87210  1409.0  101.0  283.0  64.0  250.0  711.0
# 87211  1284.0  115.0  229.0  79.0  207.0  654.0
# 87212   726.0  110.0   83.0  25.0   79.0  429.0
#
# [3386 rows x 11 columns])
# ('Город Санкт-Петербург',                       region                                         tik  \
# 87213  Город Санкт-Петербург   Территориальная избирательная комиссия №1
# 87214  Город Санкт-Петербург   Территориальная избирательная комиссия №1
# 87215  Город Санкт-Петербург   Территориальная избирательная комиссия №1
# 87216  Город Санкт-Петербург   Территориальная избирательная комиссия №1
# 87217  Город Санкт-Петербург   Территориальная избирательная комиссия №1
# ...                      ...                                         ...
# 89150  Город Санкт-Петербург  Территориальная избирательная комиссия №30
# 89151  Город Санкт-Петербург  Территориальная избирательная комиссия №30
# 89152  Город Санкт-Петербург  Территориальная избирательная комиссия №30
# 89153  Город Санкт-Петербург  Территориальная избирательная комиссия №30
# 89154  Город Санкт-Петербург  Территориальная избирательная комиссия №30
#
#              uik   total  invalid   valid    Zh     Zu     Mi     Pr      Pu
# 87213     УИК №1  1887.0     15.0  1098.0  46.0  112.0   86.0  215.0   639.0
# 87214     УИК №2  1658.0     14.0  1062.0  45.0   85.0   83.0  129.0   720.0
# 87215     УИК №3  2102.0     18.0  1178.0  66.0   67.0   94.0  168.0   783.0
# 87216     УИК №4  1605.0      7.0   818.0  33.0   78.0   59.0   79.0   569.0
# 87217     УИК №5  2191.0     17.0  1131.0  57.0   79.0  158.0   34.0   803.0
# ...          ...     ...      ...     ...   ...    ...    ...    ...     ...
# 89150  УИК №1847  1531.0      0.0  1438.0  66.0   90.0   13.0   47.0  1222.0
# 89151  УИК №1848  2916.0      0.0  2621.0  15.0   31.0   11.0   23.0  2541.0
# 89152  УИК №1989  2983.0      0.0  2682.0  48.0   59.0   11.0   16.0  2548.0
# 89153  УИК №1990  2615.0      0.0  2608.0  20.0  111.0    5.0    3.0  2469.0
# 89154  УИК №1991  1348.0      0.0  1293.0  28.0   37.0   12.0   35.0  1181.0
#
# [1937 rows x 11 columns])
# ('Еврейская автономная область',                              region             tik       uik   total  \
# 89155  Еврейская автономная область  Биробиджанская  УИК №100  1642.0
# 89156  Еврейская автономная область  Биробиджанская  УИК №101   739.0
# 89157  Еврейская автономная область  Биробиджанская  УИК №102   735.0
# 89158  Еврейская автономная область  Биробиджанская  УИК №103   711.0
# 89159  Еврейская автономная область  Биробиджанская  УИК №104   376.0
# ...                             ...             ...       ...     ...
# 89294  Еврейская автономная область    Смидовичская   УИК №81  1529.0
# 89295  Еврейская автономная область    Смидовичская   УИК №82  1539.0
# 89296  Еврейская автономная область    Смидовичская   УИК №83  1339.0
# 89297  Еврейская автономная область    Смидовичская   УИК №84  1463.0
# 89298  Еврейская автономная область    Смидовичская   УИК №85   698.0
#
#        invalid   valid     Zh     Zu    Mi    Pr     Pu
# 89155     23.0   883.0   94.0  157.0  30.0  54.0  548.0
# 89156      9.0   535.0   36.0   54.0  12.0  28.0  405.0
# 89157      8.0   460.0   32.0   57.0  18.0  31.0  322.0
# 89158      6.0   410.0   35.0   50.0  13.0  13.0  299.0
# 89159      2.0   192.0   27.0   23.0   6.0   2.0  134.0
# ...        ...     ...    ...    ...   ...   ...    ...
# 89294      6.0  1193.0  114.0  141.0  44.0  77.0  817.0
# 89295     28.0  1143.0   42.0  162.0  29.0  21.0  889.0
# 89296     12.0   763.0   72.0  135.0  39.0  63.0  454.0
# 89297     17.0   866.0   92.0  138.0  31.0  46.0  559.0
# 89298      5.0   472.0   32.0   63.0  16.0  27.0  334.0
#
# [144 rows x 11 columns])
# ('Забайкальский край',                    region         tik       uik   total  invalid   valid  \
# 16278  Забайкальский край    Агинская  УИК №912  1576.0     10.0  1238.0
# 16279  Забайкальский край    Агинская  УИК №913   510.0      3.0   476.0
# 16280  Забайкальский край    Агинская  УИК №914   480.0      0.0   425.0
# 16281  Забайкальский край    Агинская  УИК №915   523.0      1.0   507.0
# 16282  Забайкальский край    Агинская  УИК №916   547.0      1.0   467.0
# ...                   ...         ...       ...     ...      ...     ...
# 17228  Забайкальский край  Шилкинская  УИК №903    91.0      0.0    64.0
# 17229  Забайкальский край  Шилкинская  УИК №904   143.0      1.0   116.0
# 17230  Забайкальский край  Шилкинская  УИК №905   956.0      7.0   487.0
# 17231  Забайкальский край  Шилкинская  УИК №906   294.0      3.0   138.0
# 17232  Забайкальский край  Шилкинская  УИК №907   127.0      3.0    88.0
#
#          Zh    Zu    Mi    Pr     Pu
# 16278  31.0  90.0  43.0  95.0  979.0
# 16279   6.0  27.0  19.0  39.0  385.0
# 16280   2.0  21.0  11.0  36.0  355.0
# 16281   3.0  57.0   3.0  44.0  400.0
# 16282   8.0  60.0  15.0  31.0  353.0
# ...     ...   ...   ...   ...    ...
# 17228   7.0  10.0   2.0   1.0   44.0
# 17229  10.0  16.0   0.0   1.0   89.0
# 17230  22.0  67.0   9.0  12.0  377.0
# 17231   2.0  12.0   3.0   7.0  114.0
# 17232   1.0   3.0   1.0   1.0   82.0
#
# [955 rows x 11 columns])
# ('Ивановская область',                    region                 tik       uik  total  invalid  \
# 38059  Ивановская область  Верхнеландеховская  УИК №376  625.0      5.0
# 38060  Ивановская область  Верхнеландеховская  УИК №377  530.0      3.0
# 38061  Ивановская область  Верхнеландеховская  УИК №378  626.0      0.0
# 38062  Ивановская область  Верхнеландеховская  УИК №379  243.0      2.0
# 38063  Ивановская область  Верхнеландеховская  УИК №380  189.0      0.0
# ...                   ...                 ...       ...    ...      ...
# 38771  Ивановская область          Юрьевецкая  УИК №843  328.0      3.0
# 38772  Ивановская область          Юрьевецкая  УИК №844  335.0      1.0
# 38773  Ивановская область          Юрьевецкая  УИК №845  316.0      4.0
# 38774  Ивановская область          Юрьевецкая  УИК №846  217.0      0.0
# 38775  Ивановская область          Юрьевецкая  УИК №847  128.0      1.0
#
#        valid    Zh     Zu    Mi    Pr     Pu
# 38059  515.0  21.0  112.0  21.0  16.0  345.0
# 38060  441.0  20.0   89.0  20.0  21.0  291.0
# 38061  512.0  34.0   81.0  13.0  18.0  366.0
# 38062  201.0   8.0    8.0   5.0   3.0  177.0
# 38063  143.0   3.0   15.0   2.0   0.0  123.0
# ...      ...   ...    ...   ...   ...    ...
# 38771  213.0  25.0   31.0   5.0  20.0  132.0
# 38772  225.0  21.0   39.0  11.0   6.0  148.0
# 38773  219.0  11.0   67.0  16.0  10.0  115.0
# 38774  161.0  13.0   33.0   4.0   3.0  108.0
# 38775   90.0   5.0   18.0   5.0   4.0   58.0
#
# [717 rows x 11 columns])
# ('Иркутская область',                   region                 tik        uik   total  invalid  \
# 38776  Иркутская область           Ангарская    УИК №50  1758.0      7.0
# 38777  Иркутская область           Ангарская    УИК №51  1746.0     10.0
# 38778  Иркутская область           Ангарская    УИК №52  1806.0     19.0
# 38779  Иркутская область           Ангарская    УИК №53  2045.0     20.0
# 38780  Иркутская область           Ангарская    УИК №54  1474.0     17.0
# ...                  ...                 ...        ...     ...      ...
# 40696  Иркутская область  Эхирит-Булагатская  УИК №1867   257.0      2.0
# 40697  Иркутская область  Эхирит-Булагатская  УИК №1868   248.0      1.0
# 40698  Иркутская область  Эхирит-Булагатская  УИК №1869   212.0      0.0
# 40699  Иркутская область  Эхирит-Булагатская  УИК №1870   385.0      0.0
# 40700  Иркутская область  Эхирит-Булагатская  УИК №1871   192.0      0.0
#
#         valid     Zh     Zu    Mi     Pr     Pu
# 38776   721.0   76.0  195.0  37.0   53.0  360.0
# 38777   759.0   84.0  161.0  22.0   51.0  441.0
# 38778   835.0   94.0  210.0  18.0   64.0  449.0
# 38779  1018.0  106.0  309.0  58.0   89.0  456.0
# 38780   760.0   70.0  207.0  27.0  100.0  356.0
# ...       ...    ...    ...   ...    ...    ...
# 40696   128.0    4.0   21.0   7.0    2.0   94.0
# 40697   129.0   12.0   23.0   6.0    2.0   86.0
# 40698   108.0   11.0   15.0   0.0    4.0   78.0
# 40699   237.0    6.0   54.0   7.0    8.0  162.0
# 40700   116.0    1.0   33.0   3.0    3.0   76.0
#
# [1925 rows x 11 columns])
# ('Кабардино-Балкарская Республика',                                region          tik       uik   total  invalid  \
# 6881  Кабардино-Балкарская Республика   Баксанская    УИК №1  1257.0      0.0
# 6882  Кабардино-Балкарская Республика   Баксанская    УИК №2  2623.0      0.0
# 6883  Кабардино-Балкарская Республика   Баксанская    УИК №3  1301.0      0.0
# 6884  Кабардино-Балкарская Республика   Баксанская    УИК №4  1171.0      0.0
# 6885  Кабардино-Балкарская Республика   Баксанская    УИК №5  1242.0      0.0
# ...                               ...          ...       ...     ...      ...
# 7232  Кабардино-Балкарская Республика  Эльбрусская  УИК №352  1617.0      0.0
# 7233  Кабардино-Балкарская Республика  Эльбрусская  УИК №353   308.0      0.0
# 7234  Кабардино-Балкарская Республика  Эльбрусская  УИК №354   341.0      0.0
# 7235  Кабардино-Балкарская Республика  Эльбрусская  УИК №355  1521.0      0.0
# 7236  Кабардино-Балкарская Республика  Эльбрусская  УИК №356   579.0      0.0
#
#        valid    Zh     Zu    Mi    Pr      Pu
# 6881   880.0  28.0  146.0  28.0  22.0   656.0
# 6882  1862.0  54.0  333.0  55.0  44.0  1376.0
# 6883   898.0  26.0  143.0  31.0  24.0   674.0
# 6884   784.0  24.0  124.0  25.0  27.0   584.0
# 6885   844.0  27.0  144.0  31.0  18.0   624.0
# ...      ...   ...    ...   ...   ...     ...
# 7232  1148.0  41.0  186.0  27.0  14.0   880.0
# 7233   215.0   8.0   30.0   6.0   6.0   165.0
# 7234   254.0   9.0   40.0   6.0   5.0   194.0
# 7235  1079.0  39.0  180.0  24.0  14.0   822.0
# 7236   410.0  14.0   65.0   8.0  13.0   310.0
#
# [356 rows x 11 columns])
# ('Калужская область',                   region          tik       uik   total  invalid   valid  \
# 40701  Калужская область  Бабынинская    УИК №1   265.0      3.0   209.0
# 40702  Калужская область  Бабынинская    УИК №2  2257.0     21.0  1397.0
# 40703  Калужская область  Бабынинская    УИК №3   939.0     10.0   657.0
# 40704  Калужская область  Бабынинская    УИК №4   485.0      1.0   348.0
# 40705  Калужская область  Бабынинская    УИК №5   176.0      2.0   149.0
# ...                  ...          ...       ...     ...      ...     ...
# 41419  Калужская область    Юхновская  УИК №733   142.0      3.0   122.0
# 41420  Калужская область    Юхновская  УИК №734   493.0      3.0   336.0
# 41421  Калужская область    Юхновская  УИК №735   268.0      1.0   195.0
# 41422  Калужская область    Юхновская  УИК №736   317.0      1.0   274.0
# 41423  Калужская область    Юхновская  УИК №737   169.0      3.0   153.0
#
#          Zh     Zu    Mi    Pr     Pu
# 40701  23.0   33.0   3.0   8.0  142.0
# 40702  89.0  270.0  48.0  94.0  896.0
# 40703  49.0  102.0  24.0  40.0  442.0
# 40704  32.0   42.0  13.0  16.0  245.0
# 40705  13.0   29.0   7.0   3.0   97.0
# ...     ...    ...   ...   ...    ...
# 41419  12.0   22.0   2.0   6.0   80.0
# 41420  40.0   30.0   8.0  23.0  235.0
# 41421  15.0   19.0   8.0   5.0  148.0
# 41422  24.0   55.0  18.0  19.0  158.0
# 41423  11.0   27.0   5.0   4.0  106.0
#
# [723 rows x 11 columns])
# ('Камчатский край',                 region           tik       uik   total  invalid   valid  \
# 17233  Камчатский край     Алеутская  УИК №168   500.0      7.0   378.0
# 17234  Камчатский край   Быстринская  УИК №154  1832.0      8.0  1258.0
# 17235  Камчатский край   Быстринская  УИК №155   432.0      4.0   267.0
# 17236  Камчатский край  Вилючинская    УИК №85  1184.0     55.0   646.0
# 17237  Камчатский край  Вилючинская    УИК №86   173.0      2.0   121.0
# ...                ...           ...       ...     ...      ...     ...
# 17551  Камчатский край    Тигильская  УИК №172   299.0      3.0   262.0
# 17552  Камчатский край    Тигильская  УИК №173  1405.0     19.0   926.0
# 17553  Камчатский край    Тигильская  УИК №174   104.0      0.0   104.0
# 17554  Камчатский край    Тигильская  УИК №175   208.0      2.0   206.0
# 17555  Камчатский край    Тигильская  УИК №176  2221.0     24.0  1615.0
#
#           Zh     Zu    Mi     Pr      Pu
# 17233   39.0   15.0   6.0   44.0   274.0
# 17234  148.0  158.0  46.0  101.0   805.0
# 17235   27.0   19.0  10.0    9.0   202.0
# 17236   75.0   99.0  20.0   54.0   398.0
# 17237   16.0   20.0   3.0    9.0    73.0
# ...      ...    ...   ...    ...     ...
# 17551   22.0    7.0   5.0   20.0   208.0
# 17552   93.0   96.0  29.0   64.0   644.0
# 17553    2.0    0.0   3.0    1.0    98.0
# 17554   10.0    1.0   3.0    7.0   185.0
# 17555  119.0  182.0  44.0  103.0  1167.0
#
# [323 rows x 11 columns])
# ('Карачаево-Черкесская Республика',                                region              tik       uik   total  \
# 7490  Карачаево-Черкесская Республика  Адыге-Хабльская   УИК №78  2647.0
# 7491  Карачаево-Черкесская Республика  Адыге-Хабльская   УИК №79  1038.0
# 7492  Карачаево-Черкесская Республика  Адыге-Хабльская   УИК №80   578.0
# 7493  Карачаево-Черкесская Республика  Адыге-Хабльская   УИК №81   407.0
# 7494  Карачаево-Черкесская Республика  Адыге-Хабльская   УИК №82   230.0
# ...                               ...              ...       ...     ...
# 7731  Карачаево-Черкесская Республика        Ногайская  УИК №166  2848.0
# 7732  Карачаево-Черкесская Республика        Ногайская  УИК №167   167.0
# 7733  Карачаево-Черкесская Республика        Ногайская  УИК №168  1467.0
# 7734  Карачаево-Черкесская Республика        Ногайская  УИК №169   134.0
# 7735  Карачаево-Черкесская Республика        Ногайская  УИК №170  1013.0
#
#       invalid   valid   Zh     Zu    Mi   Pr      Pu
# 7490      0.0  2586.0  0.0    4.0   2.0  2.0  2578.0
# 7491      0.0  1015.0  0.0    5.0   3.0  1.0  1006.0
# 7492     16.0   549.0  3.0  111.0   6.0  9.0   420.0
# 7493      0.0   398.0  0.0    1.0   0.0  1.0   396.0
# 7494      0.0   220.0  1.0    3.0   1.0  1.0   214.0
# ...       ...     ...  ...    ...   ...  ...     ...
# 7731      0.0  2630.0  5.0  213.0  12.0  8.0  2392.0
# 7732      0.0   132.0  1.0   12.0   1.0  2.0   116.0
# 7733      0.0  1361.0  8.0  109.0  11.0  4.0  1229.0
# 7734      0.0   124.0  1.0   10.0   1.0  1.0   111.0
# 7735      0.0   909.0  1.0   72.0   8.0  4.0   824.0
#
# [246 rows x 11 columns])
# ('Кемеровская область',                     region                          tik        uik   total  \
# 41424  Кемеровская область  Анжеро-Судженская городская     УИК №1  1029.0
# 41425  Кемеровская область  Анжеро-Судженская городская     УИК №2   773.0
# 41426  Кемеровская область  Анжеро-Судженская городская     УИК №3  1148.0
# 41427  Кемеровская область  Анжеро-Судженская городская     УИК №4   815.0
# 41428  Кемеровская область  Анжеро-Судженская городская     УИК №5   958.0
# ...                    ...                          ...        ...     ...
# 43137  Кемеровская область                    Яшкинская  УИК №1712   469.0
# 43138  Кемеровская область                    Яшкинская  УИК №1713   421.0
# 43139  Кемеровская область                    Яшкинская  УИК №1714   399.0
# 43140  Кемеровская область                    Яшкинская  УИК №1715   445.0
# 43141  Кемеровская область                    Яшкинская  УИК №1716   122.0
#
#        invalid  valid    Zh    Zu    Mi    Pr     Pu
# 41424     10.0  787.0  69.0  72.0  29.0  20.0  597.0
# 41425      3.0  622.0  28.0  34.0  12.0  20.0  528.0
# 41426     18.0  920.0  81.0  49.0  20.0  37.0  733.0
# 41427      5.0  624.0  37.0  55.0  16.0  17.0  499.0
# 41428      4.0  813.0  35.0  50.0  17.0  26.0  685.0
# ...        ...    ...   ...   ...   ...   ...    ...
# 43137      3.0  328.0  24.0  10.0   3.0   3.0  288.0
# 43138      2.0  331.0  18.0  26.0   7.0   9.0  271.0
# 43139      2.0  333.0  37.0  33.0   8.0  12.0  243.0
# 43140      2.0  309.0  44.0  22.0   7.0  13.0  223.0
# 43141     10.0  100.0   5.0   4.0   2.0   0.0   89.0
#
# [1718 rows x 11 columns])
# ('Кировская область',                   region        tik        uik   total  invalid   valid  \
# 43142  Кировская область  Арбажская     УИК №1  2078.0     11.0  1334.0
# 43143  Кировская область  Арбажская     УИК №2  1471.0      6.0  1023.0
# 43144  Кировская область  Арбажская     УИК №4   195.0      0.0   146.0
# 43145  Кировская область  Арбажская     УИК №5   144.0      0.0   112.0
# 43146  Кировская область  Арбажская     УИК №6   323.0      1.0   231.0
# ...                  ...        ...        ...     ...      ...     ...
# 44348  Кировская область   Яранская  УИК №1338   276.0      0.0   156.0
# 44349  Кировская область   Яранская  УИК №1339   425.0      3.0   273.0
# 44350  Кировская область   Яранская  УИК №1340   204.0      1.0   124.0
# 44351  Кировская область   Яранская  УИК №1341   424.0      3.0   238.0
# 44352  Кировская область   Яранская  УИК №1342   434.0      1.0   253.0
#
#           Zh     Zu     Mi    Pr     Pu
# 43142  101.0  286.0  178.0  91.0  678.0
# 43143   61.0  210.0  127.0  62.0  563.0
# 43144   11.0   21.0   14.0   7.0   93.0
# 43145   11.0   12.0    9.0   4.0   76.0
# 43146    7.0   82.0   12.0   3.0  127.0
# ...      ...    ...    ...   ...    ...
# 44348   24.0   25.0    7.0   4.0   96.0
# 44349   20.0   82.0   21.0  13.0  137.0
# 44350   17.0   36.0    3.0   3.0   65.0
# 44351   36.0   40.0   13.0  11.0  138.0
# 44352   32.0   61.0   24.0   7.0  129.0
#
# [1211 rows x 11 columns])
# ('Костромская область',                     region                   tik       uik   total  invalid  \
# 44353  Костромская область          Антроповская    УИК №1  1922.0      8.0
# 44354  Костромская область          Антроповская    УИК №2  1001.0      3.0
# 44355  Костромская область          Антроповская    УИК №3   155.0      0.0
# 44356  Костромская область          Антроповская    УИК №4   193.0      0.0
# 44357  Костромская область          Антроповская    УИК №5   426.0      1.0
# ...                    ...                   ...       ...     ...      ...
# 44971  Костромская область  Шарьинская городская  УИК №557  1789.0      6.0
# 44972  Костромская область  Шарьинская городская  УИК №558  2783.0     18.0
# 44973  Костромская область  Шарьинская городская  УИК №559  2824.0     23.0
# 44974  Костромская область  Шарьинская городская  УИК №560  2816.0      6.0
# 44975  Костромская область  Шарьинская городская  УИК №561  1814.0      8.0
#
#         valid     Zh     Zu    Mi     Pr     Pu
# 44353  1228.0  106.0  384.0  56.0   70.0  612.0
# 44354   600.0   59.0  214.0  27.0   28.0  272.0
# 44355   106.0    9.0   29.0   2.0    1.0   65.0
# 44356   153.0   16.0   46.0   7.0    5.0   79.0
# 44357   273.0   34.0   71.0  12.0   12.0  144.0
# ...       ...    ...    ...   ...    ...    ...
# 44971   981.0   87.0  264.0  57.0   90.0  483.0
# 44972  1694.0  123.0  522.0  95.0  111.0  843.0
# 44973  1699.0  135.0  495.0  80.0  124.0  865.0
# 44974  1436.0  151.0  356.0  67.0   95.0  767.0
# 44975   928.0   94.0  256.0  49.0   59.0  470.0
#
# [623 rows x 11 columns])
# ('Краснодарский край',                    region                        tik        uik   total  \
# 17556  Краснодарский край                   Абинская   УИК №101  2271.0
# 17557  Краснодарский край                   Абинская   УИК №102  2145.0
# 17558  Краснодарский край                   Абинская   УИК №103  1832.0
# 17559  Краснодарский край                   Абинская   УИК №104  1411.0
# 17560  Краснодарский край                   Абинская   УИК №105  2247.0
# ...                   ...                        ...        ...     ...
# 20264  Краснодарский край  Новороссийск, Пригородная  УИК №5923  1704.0
# 20265  Краснодарский край  Новороссийск, Пригородная  УИК №5924  1463.0
# 20266  Краснодарский край  Новороссийск, Пригородная  УИК №5925  2535.0
# 20267  Краснодарский край  Новороссийск, Пригородная  УИК №5926  2196.0
# 20268  Краснодарский край  Новороссийск, Пригородная  УИК №5927  1311.0
#
#        invalid   valid     Zh     Zu    Mi     Pr      Pu
# 17556     27.0  1460.0  119.0  353.0  62.0  106.0   820.0
# 17557     33.0  1581.0  117.0  338.0  84.0  148.0   894.0
# 17558     21.0  1367.0   92.0  231.0  43.0  132.0   869.0
# 17559     17.0  1045.0  101.0  198.0  55.0   78.0   613.0
# 17560     29.0  1387.0  130.0  315.0  54.0   86.0   802.0
# ...        ...     ...    ...    ...   ...    ...     ...
# 20264      7.0  1257.0   67.0  152.0  29.0   33.0   976.0
# 20265      8.0  1175.0   80.0  155.0  35.0   76.0   829.0
# 20266      0.0  1935.0   73.0  298.0  39.0   62.0  1463.0
# 20267     29.0  1621.0   93.0  182.0  48.0  147.0  1151.0
# 20268     17.0  1009.0   74.0  136.0  18.0   28.0   753.0
#
# [2713 rows x 11 columns])
# ('Красноярский край',                   region                tik        uik   total  invalid  \
# 20269  Красноярский край           Абанская   УИК №770  2568.0     12.0
# 20270  Красноярский край           Абанская   УИК №771  2253.0     11.0
# 20271  Красноярский край           Абанская   УИК №772  1530.0      7.0
# 20272  Красноярский край           Абанская   УИК №773   263.0      1.0
# 20273  Красноярский край           Абанская   УИК №774    49.0      0.0
# ...                  ...                ...        ...     ...      ...
# 22438  Красноярский край  Тунгусско-Чунская  УИК №2259   544.0      1.0
# 22439  Красноярский край  Тунгусско-Чунская  УИК №2260    33.0      0.0
# 22440  Красноярский край  Тунгусско-Чунская  УИК №2261   148.0      2.0
# 22441  Красноярский край  Тунгусско-Чунская  УИК №2262    63.0      0.0
# 22442  Красноярский край  Тунгусско-Чунская  УИК №2263    14.0      0.0
#
#         valid     Zh     Zu    Mi    Pr     Pu
# 20269  1528.0  175.0  350.0  57.0  94.0  852.0
# 20270  1251.0  179.0  264.0  46.0  75.0  687.0
# 20271   832.0  104.0  169.0  16.0  28.0  515.0
# 20272   188.0    8.0   63.0   6.0   3.0  108.0
# 20273    49.0    3.0    7.0   1.0   1.0   37.0
# ...       ...    ...    ...   ...   ...    ...
# 22438   272.0   15.0   42.0   5.0  29.0  181.0
# 22439    29.0    2.0    2.0   0.0   1.0   24.0
# 22440    78.0    6.0   11.0   3.0   9.0   49.0
# 22441    45.0    2.0    7.0   1.0   6.0   29.0
# 22442     8.0    0.0    0.0   0.0   0.0    8.0
#
# [2174 rows x 11 columns])
# ('Курганская область',                    region           tik        uik   total  invalid  valid  \
# 44976  Курганская область  Альменевская   УИК №174  1504.0      8.0  992.0
# 44977  Курганская область  Альменевская   УИК №175  1226.0     11.0  838.0
# 44978  Курганская область  Альменевская   УИК №176   875.0      5.0  636.0
# 44979  Курганская область  Альменевская   УИК №177   252.0      1.0  192.0
# 44980  Курганская область  Альменевская   УИК №178   199.0      1.0  161.0
# ...                   ...           ...        ...     ...      ...    ...
# 46146  Курганская область   Юргамышская  УИК №1150   705.0      1.0  429.0
# 46147  Курганская область   Юргамышская  УИК №1151   603.0      2.0  370.0
# 46148  Курганская область   Юргамышская  УИК №1152  1137.0     10.0  818.0
# 46149  Курганская область   Юргамышская  УИК №1153   138.0      0.0  102.0
# 46150  Курганская область   Юргамышская  УИК №1177   518.0      4.0  313.0
#
#          Zh     Zu    Mi    Pr     Pu
# 44976  29.0  192.0  29.0  51.0  691.0
# 44977  37.0  141.0  34.0  32.0  594.0
# 44978  32.0   89.0  20.0  22.0  473.0
# 44979   4.0   56.0   2.0   6.0  124.0
# 44980   2.0   31.0   2.0   2.0  124.0
# ...     ...    ...   ...   ...    ...
# 46146  62.0   62.0  21.0  22.0  262.0
# 46147  33.0   56.0  11.0   8.0  262.0
# 46148  92.0  128.0  28.0  45.0  525.0
# 46149   6.0    5.0   0.0   5.0   86.0
# 46150  43.0   40.0   9.0  10.0  211.0
#
# [1175 rows x 11 columns])
# ('Курская область',                 region                   tik        uik   total  invalid  \
# 46151  Курская область             Беловская   УИК №265  2370.0     15.0
# 46152  Курская область             Беловская   УИК №266   305.0      3.0
# 46153  Курская область             Беловская   УИК №267   312.0      2.0
# 46154  Курская область             Беловская   УИК №268   989.0      8.0
# 46155  Курская область             Беловская   УИК №269   110.0      1.0
# ...                ...                   ...        ...     ...      ...
# 47299  Курская область  Щигровская городская  УИК №1124  1777.0     20.0
# 47300  Курская область  Щигровская городская  УИК №1125  1698.0      7.0
# 47301  Курская область  Щигровская городская  УИК №1126   918.0      3.0
# 47302  Курская область  Щигровская городская  УИК №1127  1810.0     10.0
# 47303  Курская область  Щигровская городская  УИК №1128   910.0      9.0
#
#         valid    Zh     Zu    Mi    Pr     Pu
# 46151  1554.0  97.0  380.0  48.0  92.0  937.0
# 46152   225.0  24.0   47.0   3.0  13.0  138.0
# 46153   219.0  22.0   62.0   1.0   5.0  129.0
# 46154   678.0  34.0   92.0  15.0  26.0  511.0
# 46155    85.0   6.0    9.0   4.0  12.0   54.0
# ...       ...   ...    ...   ...   ...    ...
# 47299   981.0  70.0  254.0  24.0  44.0  589.0
# 47300  1003.0  90.0  250.0  33.0  56.0  574.0
# 47301   481.0  40.0  138.0  21.0  20.0  262.0
# 47302  1009.0  57.0  325.0  33.0  51.0  543.0
# 47303   523.0  42.0  135.0  25.0  16.0  305.0
#
# [1153 rows x 11 columns])
# ('Ленинградская область',                       region             tik       uik   total  invalid  \
# 47304  Ленинградская область  Бокситогорская    УИК №1  2445.0     16.0
# 47305  Ленинградская область  Бокситогорская    УИК №2  2169.0     16.0
# 47306  Ленинградская область  Бокситогорская    УИК №3   828.0      6.0
# 47307  Ленинградская область  Бокситогорская    УИК №4  2623.0     32.0
# 47308  Ленинградская область  Бокситогорская    УИК №5  2606.0     18.0
# ...                      ...             ...       ...     ...      ...
# 48288  Ленинградская область      Тосненская  УИК №934  2371.0     12.0
# 48289  Ленинградская область      Тосненская  УИК №935  2053.0     14.0
# 48290  Ленинградская область      Тосненская  УИК №936  1871.0     12.0
# 48291  Ленинградская область      Тосненская  УИК №937  1916.0     16.0
# 48292  Ленинградская область      Тосненская  УИК №938   687.0      0.0
#
#         valid     Zh     Zu     Mi     Pr      Pu
# 47304  1578.0  115.0  266.0   72.0  101.0  1024.0
# 47305  1406.0   98.0  264.0   90.0   88.0   866.0
# 47306   544.0   36.0   76.0   34.0   33.0   365.0
# 47307  1742.0   96.0  325.0  120.0  113.0  1088.0
# 47308  1560.0   92.0  293.0  120.0  109.0   946.0
# ...       ...    ...    ...    ...    ...     ...
# 48288  1346.0  122.0  214.0   91.0  146.0   773.0
# 48289  1193.0   83.0  191.0   98.0  111.0   710.0
# 48290  1152.0   64.0  196.0   86.0  127.0   679.0
# 48291  1213.0   72.0  156.0  106.0  117.0   762.0
# 48292   335.0   32.0   55.0   25.0   28.0   195.0
#
# [989 rows x 11 columns])
# ('Липецкая область',                  region           tik       uik  total  invalid  valid    Zh  \
# 48293  Липецкая область     Воловская  УИК №214  465.0      0.0  341.0  20.0
# 48294  Липецкая область     Воловская  УИК №215  567.0      1.0  391.0  33.0
# 48295  Липецкая область     Воловская  УИК №216  620.0      6.0  402.0  21.0
# 48296  Липецкая область     Воловская  УИК №217  515.0      6.0  432.0   7.0
# 48297  Липецкая область     Воловская  УИК №218  574.0      7.0  430.0  13.0
# ...                 ...           ...       ...    ...      ...    ...   ...
# 49163  Липецкая область  Чаплыгинская  УИК №871  274.0      0.0  216.0  12.0
# 49164  Липецкая область  Чаплыгинская  УИК №872  330.0      3.0  289.0   3.0
# 49165  Липецкая область  Чаплыгинская  УИК №873  841.0      4.0  572.0  30.0
# 49166  Липецкая область  Чаплыгинская  УИК №874  793.0     12.0  647.0  37.0
# 49167  Липецкая область  Чаплыгинская  УИК №875   85.0      0.0   76.0   2.0
#
#           Zu    Mi    Pr     Pu
# 48293   34.0   6.0   5.0  276.0
# 48294   89.0  13.0   7.0  249.0
# 48295  101.0   6.0  14.0  260.0
# 48296   65.0   3.0   6.0  351.0
# 48297   58.0   7.0   6.0  346.0
# ...      ...   ...   ...    ...
# 49163   34.0   6.0   3.0  161.0
# 49164   28.0   5.0   2.0  251.0
# 49165   69.0  14.0  23.0  436.0
# 49166  106.0  36.0  31.0  437.0
# 49167    9.0   2.0   1.0   62.0
#
# [875 rows x 11 columns])
# ('Магаданская область',                     region                    tik      uik   total  invalid  \
# 49168  Магаданская область  Магаданская городская   УИК №1  2952.0     20.0
# 49169  Магаданская область  Магаданская городская   УИК №2  2867.0     18.0
# 49170  Магаданская область  Магаданская городская   УИК №3  2492.0     20.0
# 49171  Магаданская область  Магаданская городская   УИК №4  3051.0     11.0
# 49172  Магаданская область  Магаданская городская   УИК №5  1216.0      5.0
# ...                    ...                    ...      ...     ...      ...
# 49266  Магаданская область              Арманская  УИК №48  1026.0      4.0
# 49267  Магаданская область              Арманская  УИК №49    77.0      0.0
# 49268  Магаданская область              Арманская  УИК №50   430.0      1.0
# 49269  Магаданская область              Арманская  УИК №51   262.0      2.0
# 49270  Магаданская область              Арманская  УИК №52   334.0      2.0
#
#         valid     Zh     Zu    Mi     Pr     Pu
# 49168  1903.0  138.0  439.0  80.0  290.0  956.0
# 49169  1601.0  127.0  414.0  55.0  189.0  816.0
# 49170  1457.0  122.0  342.0  57.0  173.0  763.0
# 49171  1603.0  142.0  383.0  56.0  199.0  823.0
# 49172   784.0   64.0  162.0  26.0  116.0  416.0
# ...       ...    ...    ...   ...    ...    ...
# 49266   660.0   49.0  152.0  11.0   36.0  412.0
# 49267    58.0    5.0   11.0   0.0    3.0   39.0
# 49268   290.0   27.0   38.0   3.0   10.0  212.0
# 49269   166.0   16.0   17.0   3.0    7.0  123.0
# 49270   195.0   12.0   36.0  10.0   23.0  114.0
#
# [103 rows x 11 columns])
# ('Московская область',                    region                  tik        uik   total  invalid  \
# 49271  Московская область        Балашихинская     УИК №1  2441.0     19.0
# 49272  Московская область        Балашихинская     УИК №2  3111.0     44.0
# ...
# 12841  37.0   59.0  13.0   23.0   425.0
# 12842  93.0  208.0  45.0   95.0  1128.0
# 12843  85.0  138.0  45.0   71.0   985.0
# 12844  31.0   29.0  22.0   18.0   364.0
#
# [1185 rows x 11 columns])
# ('Ульяновская область',                     region                tik       uik   total  invalid  \
# 80589  Ульяновская область  Базарносызганская    УИК №1  1174.0     10.0
# 80590  Ульяновская область  Базарносызганская    УИК №2  1244.0      7.0
# 80591  Ульяновская область  Базарносызганская    УИК №3  1518.0     12.0
# 80592  Ульяновская область  Базарносызганская    УИК №4   214.0      5.0
# 80593  Ульяновская область  Базарносызганская    УИК №5   301.0      2.0
# ...                    ...                ...       ...     ...      ...
# 81577  Ульяновская область    Новоульяновская  УИК №730   856.0      7.0
# 81578  Ульяновская область    Новоульяновская  УИК №731   544.0      3.0
# 81579  Ульяновская область    Новоульяновская  УИК №732    70.0      0.0
# 81580  Ульяновская область    Новоульяновская  УИК №733  2184.0     24.0
# 81581  Ульяновская область    Новоульяновская  УИК №734   543.0      3.0
#
#         valid     Zh     Zu    Mi    Pr     Pu
# 80589   737.0   57.0  158.0  42.0  30.0  450.0
# 80590   772.0   52.0  152.0  31.0  37.0  500.0
# 80591   905.0   68.0  230.0  48.0  20.0  539.0
# 80592   148.0   15.0   21.0   6.0   0.0  106.0
# 80593   215.0   15.0   40.0  13.0  10.0  137.0
# ...       ...    ...    ...   ...   ...    ...
# 81577   503.0   46.0  145.0  15.0  33.0  264.0
# 81578   358.0   21.0   49.0  12.0   8.0  268.0
# 81579    62.0    4.0    5.0   3.0   5.0   45.0
# 81580  1223.0  132.0  284.0  40.0  57.0  710.0
# 81581   384.0   64.0   66.0  16.0   8.0  230.0
#
# [993 rows x 11 columns])
# ('Хабаровский край',                  region          tik       uik   total  invalid   valid  \
# 27185  Хабаровский край     Амурская  УИК №394    25.0      0.0    20.0
# 27186  Хабаровский край     Амурская  УИК №395  1637.0     10.0  1052.0
# 27187  Хабаровский край     Амурская  УИК №396  1748.0     12.0  1045.0
# 27188  Хабаровский край     Амурская  УИК №397  1569.0     10.0   956.0
# 27189  Хабаровский край     Амурская  УИК №398  1362.0      8.0   711.0
# ...                 ...          ...       ...     ...      ...     ...
# 28014  Хабаровский край  Хабаровская  УИК №785   952.0      3.0   488.0
# 28015  Хабаровский край  Хабаровская  УИК №786  1794.0     23.0   978.0
# 28016  Хабаровский край  Хабаровская  УИК №787  1382.0     14.0   761.0
# 28017  Хабаровский край  Хабаровская  УИК №788  2188.0      8.0  1204.0
# 28018  Хабаровский край  Хабаровская  УИК №789  2198.0     21.0  1238.0
#
#           Zh     Zu    Mi     Pr     Pu
# 27185    3.0    1.0   2.0    2.0   12.0
# 27186   90.0  253.0  60.0   83.0  566.0
# 27187   84.0  249.0  57.0   90.0  565.0
# 27188   89.0  231.0  53.0   62.0  521.0
# 27189   82.0  152.0  43.0   52.0  382.0
# ...      ...    ...   ...    ...    ...
# 28014   69.0   85.0  10.0   36.0  288.0
# 28015  156.0  162.0  25.0   72.0  563.0
# 28016  125.0   82.0  24.0   63.0  467.0
# 28017  169.0  248.0  68.0   95.0  624.0
# 28018  186.0  261.0  62.0  104.0  625.0
#
# [833 rows x 11 columns])
# ('Челябинская область',                     region            tik        uik   total  invalid   valid  \
# 81582  Челябинская область     Агаповская  УИК №1544  1943.0     10.0  1332.0
# 81583  Челябинская область     Агаповская  УИК №1545  2045.0     24.0  1288.0
# 81584  Челябинская область     Агаповская  УИК №1546  1552.0     17.0  1109.0
# 81585  Челябинская область     Агаповская  УИК №1547   462.0      2.0   321.0
# 81586  Челябинская область     Агаповская  УИК №1548   337.0      6.0   231.0
# ...                    ...            ...        ...     ...      ...     ...
# 83822  Челябинская область  Чебаркульская   УИК №514   334.0      3.0   193.0
# 83823  Челябинская область  Чебаркульская   УИК №515   157.0      1.0    83.0
# 83824  Челябинская область  Чебаркульская  УИК №2222   172.0      1.0   113.0
# 83825  Челябинская область  Чебаркульская  УИК №2223  1624.0     15.0   952.0
# 83826  Челябинская область  Чебаркульская  УИК №2259   165.0      1.0   126.0
#
#          Zh     Zu    Mi    Pr     Pu
# 81582  52.0  174.0  72.0  81.0  953.0
# 81583  59.0  155.0  54.0  70.0  950.0
# 81584  66.0  139.0  56.0  71.0  777.0
# 81585  18.0   28.0  10.0  16.0  249.0
# 81586   6.0   41.0   6.0   9.0  169.0
# ...     ...    ...   ...   ...    ...
# 83822  15.0   12.0   5.0  12.0  149.0
# 83823   8.0    4.0   1.0   0.0   70.0
# 83824  14.0    9.0   4.0   1.0   85.0
# 83825  82.0  188.0  37.0  57.0  588.0
# 83826   4.0   24.0   1.0   7.0   90.0
#
# [2245 rows x 11 columns])
# ('Чувашская Республика - Чувашия',                                region          tik        uik  total  invalid  \
# 13240  Чувашская Республика - Чувашия   Алатырская     УИК №1  684.0      7.0
# 13241  Чувашская Республика - Чувашия   Алатырская     УИК №2  311.0      0.0
# 13242  Чувашская Республика - Чувашия   Алатырская     УИК №3  419.0      6.0
# 13243  Чувашская Республика - Чувашия   Алатырская     УИК №4  453.0      0.0
# 13244  Чувашская Республика - Чувашия   Алатырская     УИК №5  611.0      9.0
# ...                               ...          ...        ...    ...      ...
# 14411  Чувашская Республика - Чувашия  Янтиковская  УИК №1172  394.0      1.0
# 14412  Чувашская Республика - Чувашия  Янтиковская  УИК №1173  102.0      0.0
# 14413  Чувашская Республика - Чувашия  Янтиковская  УИК №1174  214.0      6.0
# 14414  Чувашская Республика - Чувашия  Янтиковская  УИК №1175  790.0     12.0
# 14415  Чувашская Республика - Чувашия  Янтиковская  УИК №1176  116.0      1.0
#
#        valid    Zh    Zu    Mi    Pr     Pu
# 13240  621.0  41.0  65.0  14.0  32.0  469.0
# 13241  299.0   6.0  22.0   6.0   4.0  261.0
# 13242  367.0  16.0  39.0  14.0   1.0  297.0
# 13243  427.0  12.0  27.0  13.0   4.0  371.0
# 13244  576.0  22.0  80.0  15.0  12.0  447.0
# ...      ...   ...   ...   ...   ...    ...
# 14411  386.0   9.0  47.0  12.0   5.0  313.0
# 14412   98.0   4.0   4.0   2.0   2.0   86.0
# 14413  206.0   5.0  21.0  11.0   5.0  164.0
# 14414  753.0  20.0  72.0  26.0  16.0  619.0
# 14415  110.0   3.0  15.0   4.0   0.0   88.0
#
# [1176 rows x 11 columns])
# ('Чукотский автономный округ',                            region                   tik      uik   total  \
# 89350  Чукотский автономный округ            Анадырская   УИК №6   635.0
# 89351  Чукотский автономный округ            Анадырская   УИК №7  1114.0
# 89352  Чукотский автономный округ            Анадырская   УИК №8   782.0
# 89353  Чукотский автономный округ            Анадырская   УИК №9   527.0
# 89354  Чукотский автономный округ            Анадырская  УИК №10   267.0
# 89355  Чукотский автономный округ            Анадырская  УИК №11    86.0
# 89356  Чукотский автономный округ            Анадырская  УИК №12   110.0
# 89357  Чукотский автономный округ            Анадырская  УИК №13   478.0
# 89358  Чукотский автономный округ            Анадырская  УИК №14   147.0
# 89359  Чукотский автономный округ            Анадырская  УИК №15   428.0
# 89360  Чукотский автономный округ            Анадырская  УИК №16    45.0
# 89361  Чукотский автономный округ            Анадырская  УИК №17   978.0
# 89362  Чукотский автономный округ            Анадырская  УИК №18   155.0
# 89363  Чукотский автономный округ            Анадырская  УИК №19   241.0
# 89364  Чукотский автономный округ            Анадырская  УИК №20   252.0
# 89365  Чукотский автономный округ  Анадырская городская   УИК №1  2175.0
# 89366  Чукотский автономный округ  Анадырская городская   УИК №2  2164.0
# 89367  Чукотский автономный округ  Анадырская городская   УИК №3  2535.0
# 89368  Чукотский автономный округ  Анадырская городская   УИК №4  2510.0
# 89369  Чукотский автономный округ  Анадырская городская   УИК №5   483.0
# 89370  Чукотский автономный округ           Билибинская  УИК №21  1496.0
# 89371  Чукотский автономный округ           Билибинская  УИК №22  1514.0
# 89372  Чукотский автономный округ           Билибинская  УИК №23  1333.0
# 89373  Чукотский автономный округ           Билибинская  УИК №24   736.0
# 89374  Чукотский автономный округ           Билибинская  УИК №25   412.0
# 89375  Чукотский автономный округ           Билибинская  УИК №26   203.0
# 89376  Чукотский автономный округ           Билибинская  УИК №27   298.0
# 89377  Чукотский автономный округ           Билибинская  УИК №28   134.0
# 89378  Чукотский автономный округ           Билибинская  УИК №29   247.0
# 89379  Чукотский автономный округ           Иультинская  УИК №30  1848.0
# 89380  Чукотский автономный округ           Иультинская  УИК №31   255.0
# 89381  Чукотский автономный округ           Иультинская  УИК №32   196.0
# 89382  Чукотский автономный округ           Иультинская  УИК №33   113.0
# 89383  Чукотский автономный округ           Иультинская  УИК №34   403.0
# 89384  Чукотский автономный округ           Иультинская  УИК №35    90.0
# 89385  Чукотский автономный округ           Иультинская  УИК №36    92.0
# 89386  Чукотский автономный округ           Иультинская  УИК №37   314.0
# 89387  Чукотский автономный округ           Иультинская  УИК №38   371.0
# 89388  Чукотский автономный округ          Провиденская  УИК №39  1399.0
# 89389  Чукотский автономный округ          Провиденская  УИК №40   253.0
# 89390  Чукотский автономный округ          Провиденская  УИК №41   169.0
# 89391  Чукотский автономный округ          Провиденская  УИК №42   183.0
# 89392  Чукотский автономный округ          Провиденская  УИК №43   237.0
# 89393  Чукотский автономный округ          Провиденская  УИК №44   179.0
# 89394  Чукотский автономный округ              Чаунская  УИК №45  1296.0
# 89395  Чукотский автономный округ              Чаунская  УИК №46  1365.0
# 89396  Чукотский автономный округ              Чаунская  УИК №47  1414.0
# 89397  Чукотский автономный округ              Чаунская  УИК №48    82.0
# 89398  Чукотский автономный округ              Чаунская  УИК №49   300.0
# 89399  Чукотский автономный округ              Чаунская  УИК №50   147.0
# 89400  Чукотский автономный округ              Чаунская  УИК №51   108.0
# 89401  Чукотский автономный округ             Чукотская  УИК №52   367.0
# 89402  Чукотский автономный округ             Чукотская  УИК №53   149.0
# 89403  Чукотский автономный округ             Чукотская  УИК №54   198.0
# 89404  Чукотский автономный округ             Чукотская  УИК №55   386.0
# 89405  Чукотский автономный округ             Чукотская  УИК №56   894.0
# 89406  Чукотский автономный округ             Чукотская  УИК №57   675.0
#
#        invalid   valid     Zh     Zu    Mi     Pr      Pu
# 89350     10.0   511.0   59.0   62.0  12.0   56.0   322.0
# 89351      7.0   906.0  109.0   76.0  23.0   62.0   636.0
# 89352     11.0   579.0   62.0   59.0   6.0   47.0   405.0
# 89353      2.0   467.0   35.0   34.0  15.0   29.0   354.0
# 89354      3.0   260.0   18.0   14.0   2.0    6.0   220.0
# 89355      1.0    85.0    2.0    2.0   3.0    7.0    71.0
# 89356      1.0   109.0    5.0    1.0   1.0    4.0    98.0
# 89357      8.0   432.0    6.0    8.0   3.0    5.0   410.0
# 89358      0.0   147.0    8.0    4.0   2.0    3.0   130.0
# 89359      5.0   396.0   17.0   24.0   5.0    9.0   341.0
# 89360      1.0    44.0    5.0    6.0   0.0    2.0    31.0
# 89361     14.0   840.0   19.0   63.0  22.0   14.0   722.0
# 89362      0.0   153.0    8.0    2.0   4.0    8.0   131.0
# 89363      0.0   235.0    8.0    4.0   3.0    8.0   212.0
# 89364      0.0   252.0    7.0    1.0   0.0   15.0   229.0
# 89365     24.0  1631.0  106.0  187.0  37.0  177.0  1124.0
# 89366     26.0  1535.0  129.0  150.0  44.0  177.0  1035.0
# 89367     30.0  1777.0  151.0  188.0  49.0  222.0  1167.0
# 89368     24.0  1770.0  145.0  186.0  51.0  225.0  1163.0
# 89369      7.0   443.0   38.0   30.0  10.0   23.0   342.0
# 89370     20.0  1186.0  126.0  179.0  35.0  155.0   691.0
# 89371     20.0  1008.0  128.0  154.0  25.0  102.0   599.0
# 89372     19.0   997.0  112.0  162.0  27.0   93.0   603.0
# 89373     10.0   569.0   71.0  118.0  24.0   48.0   308.0
# 89374      9.0   378.0   41.0   26.0   5.0   15.0   291.0
# 89375      2.0   199.0   17.0   11.0   2.0    9.0   160.0
# 89376      7.0   245.0   16.0   56.0  14.0   16.0   143.0
# 89377      5.0   127.0    8.0    9.0   4.0    4.0   102.0
# 89378      3.0   214.0   22.0   27.0   6.0   14.0   145.0
# 89379     15.0  1436.0  159.0  206.0  44.0  148.0   879.0
# 89380      2.0   222.0   17.0   54.0   4.0   19.0   128.0
# 89381      1.0   195.0   10.0   14.0   4.0   15.0   152.0
# 89382      0.0   112.0    7.0    7.0   1.0    3.0    94.0
# 89383      2.0   387.0   18.0   21.0   7.0   24.0   317.0
# 89384      0.0    90.0   10.0    3.0   5.0    2.0    70.0
# 89385      2.0    90.0    2.0    0.0   1.0    1.0    86.0
# 89386      2.0   275.0   11.0   24.0   3.0   21.0   216.0
# 89387      3.0   335.0   27.0   26.0   2.0   25.0   255.0
# 89388     16.0  1133.0   84.0   84.0  36.0  115.0   814.0
# 89389      3.0   249.0   12.0    9.0   1.0    9.0   218.0
# 89390      9.0   158.0    7.0    3.0   3.0    9.0   136.0
# 89391      0.0   181.0    1.0    2.0   0.0    3.0   175.0
# 89392      4.0   215.0    2.0    5.0   4.0    6.0   198.0
# 89393      5.0   158.0    2.0    3.0   2.0    3.0   148.0
# 89394      7.0  1029.0   41.0   63.0  18.0   25.0   882.0
# 89395      5.0  1101.0   48.0   72.0   8.0   30.0   943.0
# 89396     12.0  1120.0   50.0   68.0  12.0   27.0   963.0
# 89397      1.0    80.0    8.0    5.0   2.0    9.0    56.0
# 89398      9.0   277.0   11.0   10.0   4.0    8.0   244.0
# 89399     11.0   135.0    6.0    3.0   6.0    5.0   115.0
# 89400      4.0   104.0    4.0    3.0   2.0    4.0    91.0
# 89401     18.0   326.0    3.0   11.0   4.0   10.0   298.0
# 89402      2.0   147.0    6.0    1.0   3.0    3.0   134.0
# 89403      1.0   197.0   12.0    4.0   4.0    3.0   174.0
# 89404     11.0   375.0   17.0   10.0   0.0   10.0   338.0
# 89405      7.0   754.0   29.0   68.0  17.0   89.0   551.0
# 89406      7.0   533.0   24.0   29.0   2.0   28.0   450.0  )
# ('Ямало-Ненецкий автономный округ',                                 region                   tik       uik  \
# 89407  Ямало-Ненецкий автономный округ  Губкинская городская    УИК №1
# 89408  Ямало-Ненецкий автономный округ  Губкинская городская    УИК №2
# 89409  Ямало-Ненецкий автономный округ  Губкинская городская    УИК №3
# 89410  Ямало-Ненецкий автономный округ  Губкинская городская    УИК №4
# 89411  Ямало-Ненецкий автономный округ  Губкинская городская    УИК №5
# ...                                ...                   ...       ...
# 89613  Ямало-Ненецкий автономный округ             Ямальская  УИК №205
# 89614  Ямало-Ненецкий автономный округ             Ямальская  УИК №206
# 89615  Ямало-Ненецкий автономный округ             Ямальская  УИК №207
# 89616  Ямало-Ненецкий автономный округ             Ямальская  УИК №208
# 89617  Ямало-Ненецкий автономный округ             Ямальская  УИК №209
#
#         total  invalid   valid     Zh     Zu    Mi    Pr      Pu
# 89407  2112.0     23.0  1733.0   15.0  241.0  49.0  55.0  1373.0
# 89408  2140.0     12.0  1963.0  151.0  237.0  23.0  28.0  1524.0
# 89409  1827.0     18.0  1621.0  139.0  180.0   9.0   6.0  1287.0
# 89410   861.0     12.0   724.0   72.0   79.0  12.0  19.0   542.0
# 89411  1744.0     14.0  1524.0  151.0  168.0  33.0  29.0  1143.0
# ...       ...      ...     ...    ...    ...   ...   ...     ...
# 89613  2865.0     12.0  2629.0   24.0   27.0  13.0  28.0  2537.0
# 89614  1531.0      0.0  1504.0   15.0   12.0  20.0  11.0  1446.0
# 89615  1123.0      0.0  1088.0   12.0   15.0  11.0  17.0  1033.0
# 89616  3966.0      3.0  3963.0   15.0   27.0   3.0   4.0  3914.0
# 89617  1575.0      0.0  1575.0    6.0    4.0   0.0   0.0  1565.0
#
# [211 rows x 11 columns])

# %% [markdown]
# В таком виде метод `.groupby()` дает нам немного. Мы же хотим не просто получать отдельные таблицы, а агрегировать данные по регионам ‒ суммировать все показатели (число избирателей, бюллетеней, голосов) по каждому региону. Тут на помощь придет метод `.agg()`, который выполняет агрегирование по группам.

# %%
d.groupby('region').agg('sum')
# Out:
#                                                                                tik  \
# region
# Алтайский край                   АлейскаяАлейскаяАлейскаяАлейскаяАлейскаяАлейск...
# Амурская область                 АрхаринскаяАрхаринскаяАрхаринскаяАрхаринскаяАр...
# Архангельская область            Архангельск, Исакогорская Архангельск, Исакого...
# Астраханская область             Астрахань, КировскаяАстрахань, КировскаяАстрах...
# Белгородская область             АлексеевскаяАлексеевскаяАлексеевскаяАлексеевск...
# ...                                                                            ...
# Хабаровский край                 АмурскаяАмурскаяАмурскаяАмурскаяАмурскаяАмурск...
# Челябинская область              АгаповскаяАгаповскаяАгаповскаяАгаповскаяАгапов...
# Чувашская Республика - Чувашия   АлатырскаяАлатырскаяАлатырскаяАлатырскаяАлатыр...
# Чукотский автономный округ       АнадырскаяАнадырскаяАнадырскаяАнадырскаяАнадыр...
# Ямало-Ненецкий автономный округ  Губкинская городскаяГубкинская городскаяГубкин...
#
#                                                                                uik  \
# region
# Алтайский край                   УИК №517УИК №518УИК №519УИК №520УИК №521УИК №5...
# Амурская область                 УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# Архангельская область            УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# Астраханская область             УИК №382УИК №383УИК №384УИК №385УИК №386УИК №3...
# Белгородская область             УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# ...                                                                            ...
# Хабаровский край                 УИК №394УИК №395УИК №396УИК №397УИК №398УИК №3...
# Челябинская область              УИК №1544УИК №1545УИК №1546УИК №1547УИК №1548У...
# Чувашская Республика - Чувашия   УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# Чукотский автономный округ       УИК №6УИК №7УИК №8УИК №9УИК №10УИК №11УИК №12У...
# Ямало-Ненецкий автономный округ  УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
#
#                                      total  invalid      valid       Zh  \
# region
# Алтайский край                   1961328.0  12004.0  1163426.0  97961.0
# Амурская область                  662320.0   4708.0   394996.0  39717.0
# Архангельская область             988678.0   5522.0   569492.0  51169.0
# Астраханская область              769608.0   5107.0   427496.0  21918.0
# Белгородская область             1210590.0  10209.0   889764.0  59561.0
# ...                                    ...      ...        ...      ...
# Хабаровский край                 1056125.0   8733.0   645264.0  68500.0
# Челябинская область              2757879.0  25366.0  1704033.0  97869.0
# Чувашская Республика - Чувашия    954572.0  10465.0   692492.0  39707.0
# Чукотский автономный округ         35968.0    428.0    28909.0   2106.0
# Ямало-Ненецкий автономный округ   358834.0   2669.0   332293.0  17456.0
#
#                                        Zu       Mi        Pr         Pu
# region
# Алтайский край                   261665.0  45883.0   83778.0   674139.0
# Амурская область                  67433.0  13594.0   23070.0   251182.0
# Архангельская область             91648.0  33223.0   60108.0   333344.0
# Астраханская область              67662.0  18595.0   21873.0   297448.0
# Белгородская область             211079.0  35601.0   49807.0   533716.0
# ...                                   ...      ...       ...        ...
# Хабаровский край                 115436.0  31944.0   62145.0   367239.0
# Челябинская область              254542.0  88177.0  138907.0  1124538.0
# Чувашская Республика - Чувашия   144676.0  31201.0   38838.0   438070.0
# Чукотский автономный округ         2651.0    633.0    2209.0    21310.0
# Ямало-Ненецкий автономный округ   18738.0   4979.0    7807.0   283313.0
#
# [80 rows x 10 columns]

# %% [markdown]
# Сначала в `.groupby()` мы указали переменную, по которой нужно выполнить группировку, затем в `.agg()` мы указали функцию, которую нужно выполнить. В нашем случае это 'sum', поскольку нам нужно просто сложить все показатели в пределах одного региона. Применять можно и другие функции, например, считать среднее:

# %%
#d.groupby('region').agg('mean').head() # mean - среднее

# %% [markdown]
# Или сразу несколько статистик. которые можно указать в `.agg()` в виде списка.

# %%
#d.groupby('region').agg(['mean', 'median']).head() # среднее и медиана

# %% [markdown]
# Кроме того, внутри `.agg()` можно указывать свои функции. Например, нас интересует разница между максимальным и минимальным значением. Сначала напишем функцию `my_diff`, которая будет определять такую разность:

# %%
def my_diff(x):
    return max(x) - min(x)

# %% [markdown]
# Проверим, как она работает:

# %%
my_diff([4, 6, 18]) # все верно, 8 - 4 = 4
# Out:
# 14

# %% [markdown]
# Теперь используем эту функцию внутри `.agg()`:

# %%
#d.groupby('region').agg(my_diff).head() # везде смотрим на первые 5 строк

# %% [markdown]
# Возможностей у метода `.agg()` много.
# Все, что мы пока сделали, очень интересно, но есть проблема: все данные пока даны в абсолютных значениях, не в процентах. Это неудобно. Давайте сгруппируем данные по региону и добавим в базу с агрегированными данными новые столбцы: явка в процентах и проценты голосов за каждого кандидата.
#
# Для этого необходимо вспомнить, как считается явка и проценты голосов. Явка считается так: суммируем число действительных и недействительных бюллетеней. Чтобы получить явку в процентах, делим явку на общее число зарегистрированных избирателей и домножаем на 100, чтобы перевести долю в проценты. Проценты голосов за кандидатов считаем от явки, берем число голосов за кандидата, делим на явку и домножаем на 100. Проделаем это поэтапно.
#
# Сначала сохраним результат агрегирования в переменную `regs` и добавим новый столбец для явки в абсолютных значениях (в голосах).

# %%
regs = d.groupby('region').agg('sum')

regs["turnout"] = regs.invalid + regs.valid # новый столбец - сумма двух старых
regs.head(3)
# Out:
#                                                                      tik  \
# region
# Алтайский край         АлейскаяАлейскаяАлейскаяАлейскаяАлейскаяАлейск...
# Амурская область       АрхаринскаяАрхаринскаяАрхаринскаяАрхаринскаяАр...
# Архангельская область  Архангельск, Исакогорская Архангельск, Исакого...
#
#                                                                      uik  \
# region
# Алтайский край         УИК №517УИК №518УИК №519УИК №520УИК №521УИК №5...
# Амурская область       УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# Архангельская область  УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
#
#                            total  invalid      valid       Zh        Zu  \
# region
# Алтайский край         1961328.0  12004.0  1163426.0  97961.0  261665.0
# Амурская область        662320.0   4708.0   394996.0  39717.0   67433.0
# Архангельская область   988678.0   5522.0   569492.0  51169.0   91648.0
#
#                             Mi       Pr        Pu    turnout
# region
# Алтайский край         45883.0  83778.0  674139.0  1175430.0
# Амурская область       13594.0  23070.0  251182.0   399704.0
# Архангельская область  33223.0  60108.0  333344.0   575014.0

# %% [markdown]
# Теперь добавим столбец с явкой в процентах:

# %%
regs["turnout_perc"] = round(regs.turnout / regs.total * 100, 2)
regs.head(3)
# Out:
#                                                                      tik  \
# region
# Алтайский край         АлейскаяАлейскаяАлейскаяАлейскаяАлейскаяАлейск...
# Амурская область       АрхаринскаяАрхаринскаяАрхаринскаяАрхаринскаяАр...
# Архангельская область  Архангельск, Исакогорская Архангельск, Исакого...
#
#                                                                      uik  \
# region
# Алтайский край         УИК №517УИК №518УИК №519УИК №520УИК №521УИК №5...
# Амурская область       УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# Архангельская область  УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
#
#                            total  invalid      valid       Zh        Zu  \
# region
# Алтайский край         1961328.0  12004.0  1163426.0  97961.0  261665.0
# Амурская область        662320.0   4708.0   394996.0  39717.0   67433.0
# Архангельская область   988678.0   5522.0   569492.0  51169.0   91648.0
#
#                             Mi       Pr        Pu    turnout  turnout_perc
# region
# Алтайский край         45883.0  83778.0  674139.0  1175430.0         59.93
# Амурская область       13594.0  23070.0  251182.0   399704.0         60.35
# Архангельская область  33223.0  60108.0  333344.0   575014.0         58.16

# %% [markdown]
# Осталось проделать аналогичные операции для голосов за разных кандидатов. Но повторять одно и то же пять раз не хочется (а что бы мы делали, если бы кандидатов было больше?). Давайте напишем функцию, которая будет принимать на вход столбец, делить все его значения на значения из столбца *turnout* и переводить все в проценты.

# %%
def to_perc(x):
    return round(x / regs.turnout * 100, 2)

# %% [markdown]
# А теперь выберем из базы данных столбцы с голосами за кандидатов и применим к ним нашу функцию.

# %%
perc = regs[['Zh' ,'Zu', 'Mi', 'Pr', 'Pu']].apply(to_perc, axis = 0) # axis = 0 - по столбцам, не по строкам 
perc.head(3)
# Out:
#                          Zh     Zu    Mi     Pr     Pu
# region
# Алтайский край         8.33  22.26  3.90   7.13  57.35
# Амурская область       9.94  16.87  3.40   5.77  62.84
# Архангельская область  8.90  15.94  5.78  10.45  57.97

# %% [markdown]
# Нужно переименовать столбцы в базе `perc`. Давайте сделаем это по-умному: возьмем названия столбцов в `perc` и приклеим к ним часть с `_perc`, чтобы названия столбцов с показателями в процентах отличались от показателей в абсолютных числах.

# %%
old_cols = list(perc.columns)
old_cols
# Out:
# ['Zh', 'Zu', 'Mi', 'Pr', 'Pu']

# %%
new_cols = [x + "_perc" for x in old_cols]
new_cols
# Out:
# ['Zh_perc', 'Zu_perc', 'Mi_perc', 'Pr_perc', 'Pu_perc']

# %%
perc.columns = new_cols

# %%
perc.head(3)
# Out:
#                        Zh_perc  Zu_perc  Mi_perc  Pr_perc  Pu_perc
# region
# Алтайский край            8.33    22.26     3.90     7.13    57.35
# Амурская область          9.94    16.87     3.40     5.77    62.84
# Архангельская область     8.90    15.94     5.78    10.45    57.97

# %% [markdown]
# А теперь соединим нашу таблицу `regs` с таблицей `perc`, чтобы все показатели были в одном месте. Для этого просто склеим две таблицы по столбцам с помощью метода `.concat()`.

# %%
final = pd.concat([regs, perc], axis = 1) # axis = 1 - по столбцам

# %%
final.head()
# Out:
#                                                                      tik  \
# region
# Алтайский край         АлейскаяАлейскаяАлейскаяАлейскаяАлейскаяАлейск...
# Амурская область       АрхаринскаяАрхаринскаяАрхаринскаяАрхаринскаяАр...
# Архангельская область  Архангельск, Исакогорская Архангельск, Исакого...
# Астраханская область   Астрахань, КировскаяАстрахань, КировскаяАстрах...
# Белгородская область   АлексеевскаяАлексеевскаяАлексеевскаяАлексеевск...
#
#                                                                      uik  \
# region
# Алтайский край         УИК №517УИК №518УИК №519УИК №520УИК №521УИК №5...
# Амурская область       УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# Архангельская область  УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
# Астраханская область   УИК №382УИК №383УИК №384УИК №385УИК №386УИК №3...
# Белгородская область   УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
#
#                            total  invalid      valid       Zh        Zu  \
# region
# Алтайский край         1961328.0  12004.0  1163426.0  97961.0  261665.0
# Амурская область        662320.0   4708.0   394996.0  39717.0   67433.0
# Архангельская область   988678.0   5522.0   569492.0  51169.0   91648.0
# Астраханская область    769608.0   5107.0   427496.0  21918.0   67662.0
# Белгородская область   1210590.0  10209.0   889764.0  59561.0  211079.0
#
#                             Mi       Pr        Pu    turnout  turnout_perc  \
# region
# Алтайский край         45883.0  83778.0  674139.0  1175430.0         59.93
# Амурская область       13594.0  23070.0  251182.0   399704.0         60.35
# Архангельская область  33223.0  60108.0  333344.0   575014.0         58.16
# Астраханская область   18595.0  21873.0  297448.0   432603.0         56.21
# Белгородская область   35601.0  49807.0  533716.0   899973.0         74.34
#
#                        Zh_perc  Zu_perc  Mi_perc  Pr_perc  Pu_perc
# region
# Алтайский край            8.33    22.26     3.90     7.13    57.35
# Амурская область          9.94    16.87     3.40     5.77    62.84
# Архангельская область     8.90    15.94     5.78    10.45    57.97
# Астраханская область      5.07    15.64     4.30     5.06    68.76
# Белгородская область      6.62    23.45     3.96     5.53    59.30

# %%
final.loc[['Кировская область','Нижегородская область']]
# Out:
#                                                                      tik  \
# region
# Кировская область      АрбажскаяАрбажскаяАрбажскаяАрбажскаяАрбажскаяА...
# Нижегородская область  АрдатовскаяАрдатовскаяАрдатовскаяАрдатовскаяАр...
#
#                                                                      uik  \
# region
# Кировская область      УИК №1УИК №2УИК №4УИК №5УИК №6УИК №7УИК №8УИК ...
# Нижегородская область  УИК №1УИК №2УИК №3УИК №4УИК №5УИК №6УИК №7УИК ...
#
#                            total  invalid      valid        Zh        Zu  \
# region
# Кировская область      1125794.0   7864.0   682321.0   54531.0  127982.0
# Нижегородская область  2777766.0  17366.0  1840587.0  110808.0  353964.0
#
#                             Mi        Pr         Pu    turnout  turnout_perc  \
# region
# Кировская область      36005.0   63993.0   399810.0   690185.0         61.31
# Нижегородская область  63189.0  125432.0  1187194.0  1857953.0         66.89
#
#                        Zh_perc  Zu_perc  Mi_perc  Pr_perc  Pu_perc
# region
# Кировская область         7.90    18.54     5.22     9.27    57.93
# Нижегородская область     5.96    19.05     3.40     6.75    63.90
