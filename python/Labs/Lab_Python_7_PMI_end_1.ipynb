# %% [markdown]
# #                                    Лабораторная работа №7

# %% [markdown]
# ## Pandas: Обработка данных

# %% [markdown]
# **1.** Описание исходных данных приведено тут: https://www.kaggle.com/janiobachmann/math-students. Вам предложены измененные данные.

# %%
# Открываем таблицу с данными об учениках 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os

data = pd.read_csv('math_students.csv', delimiter=',')
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   M   15       U     LE3       A     3     2  services     other
# 3     GP   F   15       U     LE3       T     1     1   at_home     other
# 4     GP   F   15       U     GT3       T     4     2    health  services
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        2      2     1     1      1        0  16  18  19
# 3  ...      4        3      2     2     3      3       10   7   8  10
# 4  ...      3        2      2     1     1      5        2  15  14  15
#
# [5 rows x 33 columns]

# %% [markdown]
# Проанализируйте данные - выведите всю возможную информацию, типы данных, распределение по каждому столбцу.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      423 non-null    object
#  1   sex         423 non-null    object
#  2   age         423 non-null    int64
#  3   address     423 non-null    object
#  4   famsize     423 non-null    object
#  5   Pstatus     423 non-null    object
#  6   Medu        423 non-null    int64
#  7   Fedu        423 non-null    int64
#  8   Mjob        420 non-null    object
#  9   Fjob        423 non-null    object
#  10  reason      422 non-null    object
#  11  guardian    421 non-null    object
#  12  traveltime  423 non-null    int64
#  13  studytime   423 non-null    int64
#  14  failures    423 non-null    int64
#  15  schoolsup   423 non-null    object
#  16  famsup      421 non-null    object
#  17  paid        423 non-null    object
#  18  activities  423 non-null    object
#  19  nursery     423 non-null    object
#  20  higher      423 non-null    object
#  21  internet    423 non-null    object
#  22  romantic    423 non-null    object
#  23  famrel      423 non-null    int64
#  24  freetime    423 non-null    int64
#  25  goout       423 non-null    int64
#  26  Dalc        423 non-null    int64
#  27  Walc        423 non-null    int64
#  28  health      423 non-null    int64
#  29  absences    423 non-null    int64
#  30  G1          423 non-null    int64
#  31  G2          423 non-null    int64
#  32  G3          423 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 109.2+ KB

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  423.000000  423.000000  423.000000  423.000000  423.000000  423.000000
# mean    16.692671    2.761229    2.539007    1.456265    2.037825    0.321513
# std      1.284290    1.089463    1.080971    0.696880    0.833816    0.729010
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    3.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  423.000000  423.000000  423.000000  423.000000  423.000000  423.000000
# mean     4.803783    3.224586    3.094563    1.475177    2.281324    3.581560
# std     17.627445    0.990074    1.110290    0.894281    1.278256    1.382813
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max    366.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2           G3
# count  423.000000  423.000000  423.000000   423.000000
# mean     5.529551   10.936170   10.742317    26.446809
# std      7.819859    3.310645    3.739412   329.422317
# min      0.000000    3.000000    0.000000     0.000000
# 25%      0.000000    8.000000    9.000000     8.000000
# 50%      4.000000   11.000000   11.000000    11.000000
# 75%      8.000000   13.000000   13.000000    14.000000
# max     75.000000   19.000000   19.000000  6785.000000

# %% [markdown]
# При наличии нелогичных данных или пустых значений - постарайтесь исправить то, что можно, а при невозможности исправления, удалите соответствующие строки. Фиксируйте, какие изменения вы выполняете.

# %%
# Выведем строки, которые содержат пропущенные данные
filtered_data = data[data.isna().any(axis=1)]
filtered_data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 222     GP   M   18       U     LE3       T     2     1      NaN     other
# 371     MS   M   17       U     GT3       T     2     3      NaN  services
# 375     MS   F   18       U     GT3       T     2     3  at_home  services
# 393     MS   F   18       U     GT3       T     2     3  at_home  services
# 416     MS   M   17       U     GT3       T     2     3      NaN  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2    G3
# 222  ...      4        3      2     4     5      3       14  10   8     9
# 371  ...      4        4      3     1     1      3        2  11  11    10
# 375  ...      5        2      3     1     2      4        0  11  10  6785
# 393  ...      5        2      3     1     2      4        0  11  10    10
# 416  ...      4        4      3     1     1      3        2  11  11    10
#
# [5 rows x 33 columns]

# %%
# Удаление строк, содержащих пропущенные значения
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 422
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      418 non-null    object
#  1   sex         418 non-null    object
#  2   age         418 non-null    int64
#  3   address     418 non-null    object
#  4   famsize     418 non-null    object
#  5   Pstatus     418 non-null    object
#  6   Medu        418 non-null    int64
#  7   Fedu        418 non-null    int64
#  8   Mjob        418 non-null    object
#  9   Fjob        418 non-null    object
#  10  reason      418 non-null    object
#  11  guardian    418 non-null    object
#  12  traveltime  418 non-null    int64
#  13  studytime   418 non-null    int64
#  14  failures    418 non-null    int64
#  15  schoolsup   418 non-null    object
#  16  famsup      418 non-null    object
#  17  paid        418 non-null    object
#  18  activities  418 non-null    object
#  19  nursery     418 non-null    object
#  20  higher      418 non-null    object
#  21  internet    418 non-null    object
#  22  romantic    418 non-null    object
#  23  famrel      418 non-null    int64
#  24  freetime    418 non-null    int64
#  25  goout       418 non-null    int64
#  26  Dalc        418 non-null    int64
#  27  Walc        418 non-null    int64
#  28  health      418 non-null    int64
#  29  absences    418 non-null    int64
#  30  G1          418 non-null    int64
#  31  G2          418 non-null    int64
#  32  G3          418 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 111.0+ KB

# %% [markdown]
# Если в таблице имеются повторяющиеся строки - удалите их.

# %%
#duplicate = data.duplicated()
#print(duplicate)
#data[duplicate]

# Удаляем дублированные строки
data_unique = data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 422
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      418 non-null    object
#  1   sex         418 non-null    object
#  2   age         418 non-null    int64
#  3   address     418 non-null    object
#  4   famsize     418 non-null    object
#  5   Pstatus     418 non-null    object
#  6   Medu        418 non-null    int64
#  7   Fedu        418 non-null    int64
#  8   Mjob        418 non-null    object
#  9   Fjob        418 non-null    object
#  10  reason      418 non-null    object
#  11  guardian    418 non-null    object
#  12  traveltime  418 non-null    int64
#  13  studytime   418 non-null    int64
#  14  failures    418 non-null    int64
#  15  schoolsup   418 non-null    object
#  16  famsup      418 non-null    object
#  17  paid        418 non-null    object
#  18  activities  418 non-null    object
#  19  nursery     418 non-null    object
#  20  higher      418 non-null    object
#  21  internet    418 non-null    object
#  22  romantic    418 non-null    object
#  23  famrel      418 non-null    int64
#  24  freetime    418 non-null    int64
#  25  goout       418 non-null    int64
#  26  Dalc        418 non-null    int64
#  27  Walc        418 non-null    int64
#  28  health      418 non-null    int64
#  29  absences    418 non-null    int64
#  30  G1          418 non-null    int64
#  31  G2          418 non-null    int64
#  32  G3          418 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 111.0+ KB

# %% [markdown]
# После предобработки данных визуализируйте распределение значений всех столбцов.

# %%
data.hist(bins=50, figsize=(20,15), color='r')
plt.show()

# %% [markdown]
# Следующие задания выполните на предобработанных данных.

# %% [markdown]
# * Какая причина выбора школы была самой частой? В качестве ответа приведите соответствующее значение признака.

# %%
data['reason'].value_counts()
# Out:
# course        157
# home          114
# reputation    110
# other          37
# Name: reason, dtype: int64

# %%
print('Наиболее частая причина выбора школы - ', data['reason'].mode().to_list()[0])
# Out:
# Наиболее частая причина выбора школы -  course

# %% [markdown]
# * Найдите количество студентов, у родителей (одного или обоих - рассмотрите оба варианта) которых нет никакого образования.

# %%
data[(data['Medu'] == 0) | (data['Fedu'] == 0)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 80      GP   M   15       U     GT3       T     4     0  teacher    other
# 133     GP   F   19       U     GT3       T     0     1  at_home    other
# 177     GP   M   16       U     GT3       T     1     0    other    other
# 265     GP   M   16       U     GT3       T     0     2    other    other
# 340     GP   F   17       U     LE3       T     0     2  at_home  at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 80   ...      3        4      3     1     1      1        8  11  11  10
# 133  ...      3        4      2     1     1      5        2   7   8   9
# 177  ...      4        3      2     1     1      3        2  13  15  16
# 265  ...      4        3      2     2     4      5        0  13  15  15
# 340  ...      3        3      3     2     3      2        0  16  15  15
#
# [5 rows x 33 columns]

# %%
print('Количество студентов, у которых хотя бы у одного родителя нет образования = ', len(data[(data['Medu'] == 0) | (data['Fedu'] == 0)]))
# Out:
# Количество студентов, у которых хотя бы у одного родителя нет образования =  5

# %%
data[(data['Medu'] == 0) & (data['Fedu'] == 0)]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
print('Количество студентов, у которых у обоих родителей нет образования = ', len(data[(data['Medu'] == 0) & (data['Fedu'] == 0)]))
# Out:
# Количество студентов, у которых у обоих родителей нет образования =  0

# %% [markdown]
# * Найдите минимальный возраст учащегося школы Mousinho da Silveira.

# %%
df = data[data['school'] == 'MS']
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 365     MS   M   18       R     GT3       T     3     2     other     other
# 366     MS   M   19       R     GT3       T     1     1     other  services
# 367     MS   M   17       U     GT3       T     3     3    health     other
# 368     MS   M   18       U     LE3       T     1     3   at_home   service
# 369     MS   M   19       R     GT3       T     1     1     other     other
# 370     MS   M   17       R     GT3       T     4     3  services     other
# 372     MS   F   18       U     GT3       T     3     3  services  services
# 373     MS   F   17       R     GT3       T     4     4   teacher  services
# 374     MS   F   17       U     LE3       А     3     2  services     other
# 376     MS   M   18       U     LE3       T     1     1     other  services
# 377     MS   F   18       U     LE3       T     1     1   at_home  services
# 378     MS   F   18       R     LE3       A     1     4   at_home     other
# 379     MS   M   18       R     LE3       T     1     1   at_home     other
# 380     MS   F   18       U     GT3       T     3     3  services  services
# 381     MS   F   17       U     LE3       T     4     4   at_home   at_home
# 382     MS   F   17       R     GT3       T     1     2     other  services
# 383     MS   M   18       R     GT3       T     1     3   at_home     other
# 384     MS   M   18       U     LE3       T     4     4   teacher  services
# 385     MS   F   17       R     GT3       T     1     1     other  services
# 386     MS   F   18       U     GT3       T     2     3   at_home  services
# 387     MS   F   18       R     GT3       T     4     4     other   teacher
# 388     MS   F   19       U     LE3       T     3     2  services  services
# 389     MS   M   18       R     LE3       T     1     2   at_home  services
# 390     MS   F   17       U     GT3       T     2     2     other   at_home
# 391     MS   F   17       R     GT3       T     1     2     other     other
# 392     MS   F   18       R     LE3       T     4     4     other     other
# 394     MS   F   18       R     GT3       T     1     1     other     other
# 395     MS   F   20       U     GT3       T     4     2    health     other
# 396     MS   F   18       R     LE3       T     4     4   teacher  services
# 397     MS   F   18       U     GT3       T     3     3     other     other
# 398     MS   F   17       R     GT3       T     3     1   at_home     other
# 399     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 400     MS   M   18       R     GT3       T     2     1     other     other
# 401     MS   M   17       U     GT3       T     2     3     other  services
# 402     MS   M   19       R     GT3       T     1     1     other  services
# 403     MS   M   18       R     GT3       T     4     2     other     other
# 404     MS   F   18       R     GT3       T     2     2   at_home     other
# 405     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 406     MS   F   19      RR     GT3       T     2     3  services     other
# 407     MS   F   18       U     LE3       T     3     1   teacher  services
# 408     MS   F   18       U     GT3       T     1     1     other     other
# 409     MS   M   20       U     LE3       A     2     2  services  services
# 410     MS   M   17       U     LE3       T     3     1  services  services
# 411     MS   M   21       R     GT3       T     1     1     other     other
# 413     MS   M   18       R     LE3       T     3     2  services     other
# 414     MS   M   19       U     LE3       T     1     1     other   at_home
# 415     MS   M   17       R     GT3       T     4     3  services     other
# 417     MS   F   18       U     GT3       T     3     3  services  services
# 418     MS   F   17       R     GT3       T     4     4   teacher  services
# 419     MS   F   17       U     LE3       А     3     2  services     other
# 420     MS   F   19      RR     GT3       T     2     3  services     other
# 421     MS   F   18       U     LE3       T     3     1   teacher  services
# 422     MS   F   18       U     GT3       T     1     1     other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 365  ...      2        5      5     5     5      5       10  11  13  13
# 366  ...      5        4      4     3     3      2        8   8   7   8
# 367  ...      4        5      4     2     3      3        2  13  13  13
# 368  ...      4        3      3     2     3      3        7   8   7   8
# 369  ...      4        4      4     3     3      5        4   8   8   8
# 370  ...      4        5      5     1     3      2        4  13  11  11
# 372  ...      5        3      4     1     1      5        0  10   9   9
# 373  ...      4        3      3     1     2      5        4  12  13  13
# 374  ...      1        2      3     1     2      5        2  12  12  11
# 376  ...      3        3      2     1     2      3        4  10  10  10
# 377  ...      5        3      2     1     1      4        0  18  16  16
# 378  ...      4        3      4     1     4      5        0  13  13  13
# 379  ...      4        4      3     2     3      5        2  13  12  12
# 380  ...      4        3      2     1     3      3        0  11  11  10
# 381  ...      2        3      4     1     1      1        0  16  15  15
# 382  ...      3        2      2     1     2      3        0  12  11  12
# 383  ...      3        3      4     2     4      3        4  10  10  10
# 384  ...      4        2      2     2     2      5        0  13  13  13
# 385  ...      5        2      1     1     2      1        0   7   6   0
# 386  ...      5        2      3     1     2      4        0  11  10  10
# 387  ...      3        2      2     4     2      5       10  14  12  11
# 388  ...      3        2      2     1     1      3        4   7   7   9
# 389  ...      4        3      3     2     3      3        3  14  12  12
# 390  ...      3        4      3     1     1      3        8  13  11  11
# 391  ...      3        5      5     1     3      1       14   6   5   5
# 392  ...      5        4      4     1     1      1        0  19  18  19
# 394  ...      4        3      2     1     2      4        2   8   8  10
# 395  ...      5        4      3     1     1      3        4  15  14  15
# 396  ...      5        4      3     3     4      2        4   8   9  10
# 397  ...      4        1      3     1     2      1        0  15  15  15
# 398  ...      4        5      4     2     3      1       17  10  10  10
# 399  ...      3        2      4     1     4      2        4  15  14  14
# 400  ...      4        4      3     1     3      5        5   7   6   7
# 401  ...      4        4      3     1     1      3        2  11  11  10
# 402  ...      4        3      2     1     3      5        0   6   5   0
# 403  ...      5        4      3     4     3      3       14   6   5   5
# 404  ...      5        3      3     1     3      4        2  10   9  10
# 405  ...      4        4      3     2     2      5        7   6   5   6
# 406  ...      5        4      2     1     2      5        0   7   5   0
# 407  ...      4        3      4     1     1      1        0   7   9   8
# 408  ...      1        1      1     1     1      5        0   6   5   0
# 409  ...      5        5      4     4     5      4       11   9   9   9
# 410  ...      2        4      5     3     4      2        3  14  16  16
# 411  ...      5        5      3     3     3      3        3  10   8   7
# 413  ...      4        4      1     3     4      5        0  11  12  10
# 414  ...      3        2      3     3     3      5        5   8   9   9
# 415  ...      4        5      5     1     3      2        4  13  11  11
# 417  ...      5        3      4     1     1      5        0  10   9   9
# 418  ...      4        3      3     1     2      5        4  12  13  13
# 419  ...      1        2      3     1     2      5        2  12  12  11
# 420  ...      5        4      2     1     2      5        0   7   5   0
# 421  ...      4        3      4     1     1      1        0   7   9   8
# 422  ...      1        1      1     1     1      5        0   6   5   0
#
# [53 rows x 33 columns]

# %%
print('Минимальный возраст учеников школы Mousinho da Silveira = ', df['age'].min())
# Out:
# Минимальный возраст учеников школы Mousinho da Silveira =  17

# %% [markdown]
# * Найдите количество студентов, имеющих нечетное число пропусков.

# %%
df = data[data['absences'] % 2 == 1]
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 38      GP   M   16       R     GT3       A     4     4     other   teacher
# 41      GP   F   16       U     LE3       T     2     2     other     other
# 64      GP   M   18       R     GT3       T     4     3   teacher  services
# 98      GP   M   18       R     GT3       T     4     3   teacher  services
# 219     GP   F   16       U     GT3       A     3     1  services     other
# 225     GP   M   17       U     LE3       T     4     4  services     other
# 227     GP   M   18       U     GT3       T     2     2  services     other
# 231     GP   M   18       U     LE3       T     3     3  services    health
# 232     GP   F   17       U     GT3       T     2     3   at_home     other
# 276     GP   F   18       U     GT3       T     4     3  services     other
# 278     GP   M   18       R     GT3       T     3     2     other     other
# 281     GP   M   18       R     LE3       A     3     4     other     other
# 286     GP   F   19       U     GT3       T     3     3     other  services
# 292     GP   F   18       R     GT3       A     3     2     other  services
# 294     GP   F   18       U     GT3       T     4     4    health    health
# 297     GP   M   17       U     LE3       A     3     2   teacher  services
# 298     GP   F   18       R     LE3       T     1     1   at_home     other
# 302     GP   F   18       U     GT3       T     2     2   at_home   at_home
# 305     GP   M   18       U     LE3       A     4     4   teacher   teacher
# 306     GP   M   18       U     GT3       T     4     2   teacher     other
# 315     GP   M   18       U     LE3       T     4     4   teacher   teacher
# 328     GP   M   19       U     GT3       T     1     2     other  services
# 333     GP   F   18       U     GT3       T     4     3     other     other
# 336     GP   F   17       U     GT3       A     4     3  services  services
# 338     GP   F   17       R     LE3       T     2     2  services  services
# 339     GP   F   17       U     GT3       T     3     1  services  services
# 341     GP   M   18       U     GT3       T     4     4     other     other
# 342     GP   M   17       U     GT3       T     3     3     other  services
# 344     GP   F   17       U     GT3       T     4     4   teacher  services
# 347     GP   F   17       R     GT3       T     2     4   at_home     other
# 354     GP   F   18       U     LE3       T     3     3  services  services
# 358     GP   M   18       U     LE3       T     3     4  services     other
# 361     GP   F   18       U     GT3       T     3     2     other  services
# 362     GP   M   18       R     GT3       T     4     3   teacher  services
# 368     MS   M   18       U     LE3       T     1     3   at_home   service
# 389     MS   M   18       R     LE3       T     1     2   at_home  services
# 398     MS   F   17       R     GT3       T     3     1   at_home     other
# 400     MS   M   18       R     GT3       T     2     1     other     other
# 405     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 409     MS   M   20       U     LE3       A     2     2  services  services
# 410     MS   M   17       U     LE3       T     3     1  services  services
# 411     MS   M   21       R     GT3       T     1     1     other     other
# 414     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 38   ...      2        4      3     1     1      5        7  15  16  15
# 41   ...      3        3      3     1     2      3       25   7  10  11
# 64   ...      5        3      2     1     2      4        9  16  15  16
# 98   ...      5        3      2     1     2      4        9  16  15  16
# 219  ...      2        3      3     2     2      4        5   7   7   7
# 225  ...      5        3      5     4     5      3       13  12  12  13
# 227  ...      4        4      4     2     4      5       15   6   7   8
# 231  ...      3        2      4     2     4      4       13   6   6   8
# 232  ...      3        3      3     1     4      3        3   7   7   8
# 276  ...      3        1      2     1     3      2       21  17  18  18
# 278  ...      5        3      2     1     1      3        1  13  12  12
# 281  ...      4        2      5     3     4      1       13  17  17  17
# 286  ...      4        3      5     3     3      5       15   9   9   9
# 292  ...      4        1      1     1     1      5       75  10   9   9
# 294  ...      2        4      4     1     1      4       15   9   8   8
# 297  ...      4        4      4     3     4      3       19  11   9  10
# 298  ...      5        2      2     1     1      3        1  12  12  12
# 302  ...      4        3      3     1     2      2        5  18  18  19
# 305  ...      5        4      3     1     1      2        9  15  13  15
# 306  ...      4        3      2     1     4      5       11  12  11  11
# 315  ...      1        4      2     2     2      1        5  16  15  16
# 328  ...      4        5      2     2     2      4        3  13  11  11
# 333  ...      4        3      4     1     1      5        9   9  10   9
# 336  ...      5        2      2     1     2      5       23  13  13  13
# 338  ...      3        3      2     2     2      3        3  11  11  11
# 339  ...      3        4      3     2     3      5        1  12  14  15
# 341  ...      4        3      3     2     2      3        3   9  12  11
# 342  ...      4        3      5     3     5      5        3  14  15  16
# 344  ...      5        4      4     1     3      4        7  10   9   9
# 347  ...      4        4      3     1     1      5        7  12  14  14
# 354  ...      5        3      3     1     1      1        7  16  15  17
# 358  ...      4        3      3     1     3      5       11  16  15  15
# 361  ...      5        4      3     2     3      1        7  13  13  14
# 362  ...      5        3      2     1     2      4        9  16  15  16
# 368  ...      4        3      3     2     3      3        7   8   7   8
# 389  ...      4        3      3     2     3      3        3  14  12  12
# 398  ...      4        5      4     2     3      1       17  10  10  10
# 400  ...      4        4      3     1     3      5        5   7   6   7
# 405  ...      4        4      3     2     2      5        7   6   5   6
# 409  ...      5        5      4     4     5      4       11   9   9   9
# 410  ...      2        4      5     3     4      2        3  14  16  16
# 411  ...      5        5      3     3     3      3        3  10   8   7
# 414  ...      3        2      3     3     3      5        5   8   9   9
#
# [43 rows x 33 columns]

# %%
print('Количество студентов, имеющих нечетное число пропусков занятий = ', len(df))
# Out:
# Количество студентов, имеющих нечетное число пропусков занятий =  43

# %% [markdown]
# * Найдите разность между средними итоговыми оценками студентов, состоящих и не состоящих в романтических отношениях. В качестве ответа приведите число, округленное до двух значащих цифр после запятой.

# %%
df = data[(data['romantic'] == 'yes')]
print("Средняя итоговая оценка студентов, состоящих в романтических отношениях =  {:.2f}".format(df['G3'].mean()))

df = data[(data['romantic'] == 'no')]
print("Средняя итоговая оценка студентов, не состоящих в романтических отношениях =  {:.2f}".format(df['G3'].mean()))
# Out:
# Средняя итоговая оценка студентов, состоящих в романтических отношениях =  9.69
# Средняя итоговая оценка студентов, не состоящих в романтических отношениях =  10.82

# %% [markdown]
# * Сколько занятий пропустило большинство студентов с самым частым значением наличия внеклассных активностей?
#
# *Примечание. В данном контексте под "большинством" подразумеваются студенты, имеющее самое частое значение пропусков. То есть в данном задании необходимо:*
#
#
# * *Определить самое частое значение наличия внеклассных активностей (да или нет).*
# * *Для группы студентов, соответствующей этому значению, рассмотреть значения признака «число пропусков».*
# * *Для каждого значения числа пропусков посчитать, сколько студентов ему соответствует.*
# * *Выбрать значение числа пропусков с наибольшим числом студентов.*

# %%
max_v = data['activities'].mode().to_list()[0]
print('Самое частое значение наличия внеклассных активностей = ', max_v)
df = data[(data['activities'] == 'yes') | (data['activities'] == 'YES')]
print(df['absences'].value_counts())
print('Наибольшее число студентов имеет ', df['absences'].mode().to_list()[0], ' пропусков занятий')
# Out:
# Самое частое значение наличия внеклассных активностей =  yes
# 0     56
# 2     39
# 4     33
# 6     17
# 8     16
# 10     9
# 14     7
# 3      4
# 16     4
# 15     3
# 12     3
# 7      3
# 11     2
# 1      2
# 9      2
# 18     2
# 20     2
# 13     1
# 5      1
# 17     1
# 22     1
# 25     1
# 30     1
# 54     1
# 56     1
# Name: absences, dtype: int64
# Наибольшее число студентов имеет  0  пропусков занятий

# %% [markdown]
# **2.** Возьмите свой набор данных (или выберите, например, на kaggle). Выполните различные возможные операции по предобработке и первичному анализу данных.
